# %%
'''Set up White Mesa Plant'''
from cortix import Cortix
from cortix import Network
from cortix import Units as unit
white_mesa = Cortix(use_mpi=False, splash=True)
wm_net = white_mesa.network = Network()
# Out:
# [12724] 2024-11-14 23:18:02,783 - cortix - INFO - Created Cortix object
# _____________________________________________________________________________
#                              L A U N C H I N G
# _____________________________________________________________________________
#       ...                                        s       .     (TAAG Fraktur)
#    xH88"`~ .x8X                                 :8      @88>
#  :8888   .f"8888Hf        u.      .u    .      .88      %8P      uL   ..
# :8888>  X8L  ^""`   ...ue888b   .d88B :@8c    :888ooo    .     .@88b  @88R
# X8888  X888h        888R Y888r ="8888f8888r -*8888888  .@88u  ""Y888k/"*P
# 88888  !88888.      888R I888>   4888>"88"    8888    888E`    Y888L
# 88888   %88888      888R I888>   4888> "      8888      888E      8888
# 88888 `> `8888>     888R I888>   4888>        8888      888E      `888N
# `8888L %  ?888   ! u8888cJ888   .d888L .+    .8888Lu=   888E   .u./"888&
#  `8888  `-*""   /   "*888*P"    ^"8888*"     ^%888*     888&  d888" Y888*"
#    "888.      :"      "Y"          "Y"         "Y"      R888" ` "Y   Y"
#      `""***~"`                                           ""
#                              https://cortix.org
# _____________________________________________________________________________

# %%
'''Setup Precipitation'''
import src.precipitation
precip = src.precipitation.Precipitation()
wm_net.module(precip)

# %%
'''Setup Network'''
wm_net.draw(engine='dot', node_shape='folder', size='600,1200')

# %%
'''Initialize run'''
end_time = 10*unit.day
time_step = 1.0*unit.day
show_time = (True, unit.hour)

for m in wm_net.modules:
    m.end_time = end_time
    m.time_step = time_step
    m.show_time = show_time

# %%
'''Run Whire Mesa and shutdown'''
white_mesa.run()
white_mesa.close()
# Out:
# [12724] 2024-11-14 23:18:04,742 - cortix - INFO - Launching Module <src.precipitation.Precipitation object at 0x000002A393A05520>
# [12724] 2024-11-14 23:18:06,718 - cortix - INFO - run()::Elapsed wall clock time [s]: 3.93
# [12724] 2024-11-14 23:18:06,719 - cortix - INFO - Closed Cortix object.
# _____________________________________________________________________________
#                            T E R M I N A T I N G
# _____________________________________________________________________________
#       ...                                        s       .     (TAAG Fraktur)
#    xH88"`~ .x8X                                 :8      @88>
#  :8888   .f"8888Hf        u.      .u    .      .88      %8P      uL   ..
# :8888>  X8L  ^""`   ...ue888b   .d88B :@8c    :888ooo    .     .@88b  @88R
# X8888  X888h        888R Y888r ="8888f8888r -*8888888  .@88u  ""Y888k/"*P
# 88888  !88888.      888R I888>   4888>"88"    8888    888E`    Y888L
# 88888   %88888      888R I888>   4888> "      8888      888E      8888
# 88888 `> `8888>     888R I888>   4888>        8888      888E      `888N
# `8888L %  ?888   ! u8888cJ888   .d888L .+    .8888Lu=   888E   .u./"888&
#  `8888  `-*""   /   "*888*P"    ^"8888*"     ^%888*     888&  d888" Y888*"
#    "888.      :"      "Y"          "Y"         "Y"      R888" ` "Y   Y"
#      `""***~"`                                           ""
#                              https://cortix.org
# _____________________________________________________________________________
# [12724] 2024-11-14 23:18:06,719 - cortix - INFO - close()::Elapsed wall clock time [s]: 3.93

# %%
'''Recover modules data'''
precip = wm_net.modules[0]

# %%
'''precipitation and plot'''
import matplotlib.pyplot as plt
(quant, time_unit) = precip.precipitation_phase.get_quantity_history('mass-flowrate')
quant.plot(x_scaling=1/unit.day, x_label='Time [d]',y_label=quant.latex_name+' ['+quant.unit+']')
plt.grid()

# %%
import matplotlib.pyplot as plt
(quant, time_unit) = precip.state_phase.get_quantity_history('tau_p')
quant.plot(x_scaling=1/unit.day, x_label='Time [d]',y_label=quant.latex_name+' ['+quant.unit+']')
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 (quant, time_unit) = precip.state_phase.get_quantity_history('tau_p')
#       3 quant.plot(x_scaling=1/unit.day, x_label='Time [d]',y_label=quant.latex_name+' ['+quant.unit+']')
#       4 plt.grid()
#
# AttributeError: 'Precipitation' object has no attribute 'state_phase'

# %%
import matplotlib.pyplot as plt
(quant, time_unit) = precip.state_phase.get_quantity_history('tau_s')
quant.plot(x_scaling=1/unit.day, x_label='Time [d]',y_label=quant.latex_name+' ['+quant.unit+']')
plt.grid()

# %%
(quant, time_unit) = precip.state_phase.get_quantity_history('heatflux')
quant.plot(x_scaling=1/unit.day, x_label='Time [d]',y_label=quant.latex_name+' ['+quant.unit+']')
plt.grid()

# %%
(quant, time_unit) = precip.state_phase.get_quantity_history('nusselt_p')
quant.plot(x_scaling=1/unit.day, x_label='Time [d]',y_label=quant.latex_name+' ['+quant.unit+']')
plt.grid()

# %%
(quant, time_unit) = precip.state_phase.get_quantity_history('nusselt_s')
quant.plot(x_scaling=1/unit.day, x_label='Time [d]',y_label=quant.latex_name+' ['+quant.unit+']')
plt.grid()
