# %% [markdown]
# **Engy-4390** Nuclear Systems Design and Analysis, UMass Lowell, Chem. Eng. Nuclear Program Fall 2023
#
# # Uranium Mill Network Dynamics Simulation
# $
#   \newcommand{\Amtrx}{\boldsymbol{\mathsf{A}}}
#   \newcommand{\Bmtrx}{\boldsymbol{\mathsf{B}}}
#   \newcommand{\Mmtrx}{\boldsymbol{\mathsf{M}}}
#   \newcommand{\Imtrx}{\boldsymbol{\mathsf{I}}}
#   \newcommand{\Pmtrx}{\boldsymbol{\mathsf{P}}}
#   \newcommand{\Lmtrx}{\boldsymbol{\mathsf{L}}}
#   \newcommand{\Umtrx}{\boldsymbol{\mathsf{U}}}
#   \newcommand{\Smtrx}{\boldsymbol{\mathsf{S}}}
#   \newcommand{\xvec}{\boldsymbol{\mathsf{x}}}
#   \newcommand{\uvar}{\boldsymbol{u}}
#   \newcommand{\fvar}{\boldsymbol{f}}
#   \newcommand{\avec}{\boldsymbol{\mathsf{a}}}
#   \newcommand{\bvec}{\boldsymbol{\mathsf{b}}}
#   \newcommand{\cvec}{\boldsymbol{\mathsf{c}}}
#   \newcommand{\rvec}{\boldsymbol{\mathsf{r}}}
#   \newcommand{\mvec}{\boldsymbol{\mathsf{m}}}
#   \newcommand{\gvec}{\boldsymbol{\mathsf{g}}}
#   \newcommand{\zerovec}{\boldsymbol{\mathsf{0}}}
#   \newcommand{\norm}[1]{\bigl\lVert{#1}\bigr\rVert}
#   \newcommand{\transpose}[1]{{#1}^\top}
#   \DeclareMathOperator{\rank}{rank}
#   \newcommand{\Power}{\mathcal{P}}
# $

# %% [markdown]
# ## Stand-Alone Leaching Module
# In construction...<br>
# [Project Repository on `GitHub`](https://github.com/dpploy/engy-4390/tree/main/projects/u-mill)

# %% [markdown]
# ---
# ## Table of Contents<a id="toc"></a>
# * [Objectives](#obj)
# * [References](#refs)
# ---

# %% [markdown]
# ## [Objectives](#toc)<a id="obj"></a>

# %% [markdown]
# - Test the implementation of coupled modules in Cortix.
# - Present an executable environment for learning how to use the Cortix modules developed for a simplified Whit Mesa Milling flowsheet.

# %%
'''Setup a White Mesa plant'''
from cortix import Cortix
from cortix import Network
import unit
white_mesa = Cortix(use_mpi=False, splash=True) # System top level
wm_net = white_mesa.network = Network() # Network
# Out:
# [16418] 2023-12-23 20:45:33,294 - cortix - INFO - Created Cortix object
# _____________________________________________________________________________
#                              L A U N C H I N G
# _____________________________________________________________________________
#       ...                                        s       .     (TAAG Fraktur)
#    xH88"`~ .x8X                                 :8      @88>
#  :8888   .f"8888Hf        u.      .u    .      .88      %8P      uL   ..
# :8888>  X8L  ^""`   ...ue888b   .d88B :@8c    :888ooo    .     .@88b  @88R
# X8888  X888h        888R Y888r ="8888f8888r -*8888888  .@88u  ""Y888k/"*P
# 88888  !88888.      888R I888>   4888>"88"    8888    888E`    Y888L
# 88888   %88888      888R I888>   4888> "      8888      888E      8888
# 88888 `> `8888>     888R I888>   4888>        8888      888E      `888N
# `8888L %  ?888   ! u8888cJ888   .d888L .+    .8888Lu=   888E   .u./"888&
#  `8888  `-*""   /   "*888*P"    ^"8888*"     ^%888*     888&  d888" Y888*"
#    "888.      :"      "Y"          "Y"         "Y"      R888" ` "Y   Y"
#      `""***~"`                                           ""
#                              https://cortix.org
# _____________________________________________________________________________

# %%
'''Setup Leaching'''
import src.leaching # this will give access to the python module docstring
leaching = src.leaching.Leaching()
wm_net.module(leaching) 
wm_net.draw(engine='circo', node_shape='folder', ports=True)

# %% [markdown]
# Documentation options:
#  + Live notebook run on *code* cell: `help(src.leaching)`
#  + On the web: [source](https://github.com/dpploy/engy-4390/blob/main/projects/u-mill/white_mesa/leaching.py)

# %%
'''Initialize run'''
end_time = 10*unit.day
time_step = 10.0*unit.minute
show_time = (True, unit.hour)

leaching.end_time = end_time
leaching.time_step = time_step
leaching.show_time = show_time

# %%
'''Run White Mesa and shutdown'''   
white_mesa.run()
white_mesa.close()
# Out:
# [16418] 2023-12-23 20:45:33,819 - cortix - INFO - Launching Module <src.leaching.Leaching object at 0x7eff080bf910>
# [16418] 2023-12-23 20:45:33,832 - cortix - INFO - Leaching::run():time[d]=0.0
# [16418] 2023-12-23 20:45:33,952 - cortix - INFO - Leaching::run():time[d]=0.0
# [16418] 2023-12-23 20:45:34,047 - cortix - INFO - Leaching::run():time[d]=0.1
# [16418] 2023-12-23 20:45:34,145 - cortix - INFO - Leaching::run():time[d]=0.1
# [16418] 2023-12-23 20:45:34,249 - cortix - INFO - Leaching::run():time[d]=0.2
# [16418] 2023-12-23 20:45:34,350 - cortix - INFO - Leaching::run():time[d]=0.2
# [16418] 2023-12-23 20:45:34,457 - cortix - INFO - Leaching::run():time[d]=0.2
# [16418] 2023-12-23 20:45:34,582 - cortix - INFO - Leaching::run():time[d]=0.3
# [16418] 2023-12-23 20:45:34,690 - cortix - INFO - Leaching::run():time[d]=0.3
# [16418] 2023-12-23 20:45:34,793 - cortix - INFO - Leaching::run():time[d]=0.4
# [16418] 2023-12-23 20:45:34,884 - cortix - INFO - Leaching::run():time[d]=0.4
# [16418] 2023-12-23 20:45:34,980 - cortix - INFO - Leaching::run():time[d]=0.5
# [16418] 2023-12-23 20:45:35,071 - cortix - INFO - Leaching::run():time[d]=0.5
# [16418] 2023-12-23 20:45:35,177 - cortix - INFO - Leaching::run():time[d]=0.5
# [16418] 2023-12-23 20:45:35,272 - cortix - INFO - Leaching::run():time[d]=0.6
# [16418] 2023-12-23 20:45:35,386 - cortix - INFO - Leaching::run():time[d]=0.6
# [16418] 2023-12-23 20:45:35,529 - cortix - INFO - Leaching::run():time[d]=0.7
# [16418] 2023-12-23 20:45:35,655 - cortix - INFO - Leaching::run():time[d]=0.7
# [16418] 2023-12-23 20:45:35,773 - cortix - INFO - Leaching::run():time[d]=0.8
# [16418] 2023-12-23 20:45:35,874 - cortix - INFO - Leaching::run():time[d]=0.8
# [16418] 2023-12-23 20:45:35,975 - cortix - INFO - Leaching::run():time[d]=0.8
# [16418] 2023-12-23 20:45:36,079 - cortix - INFO - Leaching::run():time[d]=0.9
# [16418] 2023-12-23 20:45:36,206 - cortix - INFO - Leaching::run():time[d]=0.9
# [16418] 2023-12-23 20:45:36,322 - cortix - INFO - Leaching::run():time[d]=1.0
# [16418] 2023-12-23 20:45:36,421 - cortix - INFO - Leaching::run():time[d]=1.0
# [16418] 2023-12-23 20:45:36,523 - cortix - INFO - Leaching::run():time[d]=1.0
# [16418] 2023-12-23 20:45:36,612 - cortix - INFO - Leaching::run():time[d]=1.1
# [16418] 2023-12-23 20:45:36,706 - cortix - INFO - Leaching::run():time[d]=1.1
# [16418] 2023-12-23 20:45:36,795 - cortix - INFO - Leaching::run():time[d]=1.2
# [16418] 2023-12-23 20:45:36,887 - cortix - INFO - Leaching::run():time[d]=1.2
# [16418] 2023-12-23 20:45:36,981 - cortix - INFO - Leaching::run():time[d]=1.2
# [16418] 2023-12-23 20:45:37,074 - cortix - INFO - Leaching::run():time[d]=1.3
# [16418] 2023-12-23 20:45:37,170 - cortix - INFO - Leaching::run():time[d]=1.3
# [16418] 2023-12-23 20:45:37,268 - cortix - INFO - Leaching::run():time[d]=1.4
# [16418] 2023-12-23 20:45:37,375 - cortix - INFO - Leaching::run():time[d]=1.4
# [16418] 2023-12-23 20:45:37,491 - cortix - INFO - Leaching::run():time[d]=1.5
# [16418] 2023-12-23 20:45:37,588 - cortix - INFO - Leaching::run():time[d]=1.5
# [16418] 2023-12-23 20:45:37,700 - cortix - INFO - Leaching::run():time[d]=1.5
# [16418] 2023-12-23 20:45:37,819 - cortix - INFO - Leaching::run():time[d]=1.6
# [16418] 2023-12-23 20:45:37,935 - cortix - INFO - Leaching::run():time[d]=1.6
# [16418] 2023-12-23 20:45:38,033 - cortix - INFO - Leaching::run():time[d]=1.7
# [16418] 2023-12-23 20:45:38,129 - cortix - INFO - Leaching::run():time[d]=1.7
# [16418] 2023-12-23 20:45:38,222 - cortix - INFO - Leaching::run():time[d]=1.8
# [16418] 2023-12-23 20:45:38,316 - cortix - INFO - Leaching::run():time[d]=1.8
# [16418] 2023-12-23 20:45:38,434 - cortix - INFO - Leaching::run():time[d]=1.8
# [16418] 2023-12-23 20:45:38,531 - cortix - INFO - Leaching::run():time[d]=1.9
# [16418] 2023-12-23 20:45:38,624 - cortix - INFO - Leaching::run():time[d]=1.9
# [16418] 2023-12-23 20:45:38,722 - cortix - INFO - Leaching::run():time[d]=2.0
# [16418] 2023-12-23 20:45:38,819 - cortix - INFO - Leaching::run():time[d]=2.0
# [16418] 2023-12-23 20:45:38,926 - cortix - INFO - Leaching::run():time[d]=2.0
# [16418] 2023-12-23 20:45:39,041 - cortix - INFO - Leaching::run():time[d]=2.1
# [16418] 2023-12-23 20:45:39,174 - cortix - INFO - Leaching::run():time[d]=2.1
# [16418] 2023-12-23 20:45:39,313 - cortix - INFO - Leaching::run():time[d]=2.2
# [16418] 2023-12-23 20:45:39,470 - cortix - INFO - Leaching::run():time[d]=2.2
# [16418] 2023-12-23 20:45:39,592 - cortix - INFO - Leaching::run():time[d]=2.2
# [16418] 2023-12-23 20:45:39,709 - cortix - INFO - Leaching::run():time[d]=2.3
# [16418] 2023-12-23 20:45:39,804 - cortix - INFO - Leaching::run():time[d]=2.3
# [16418] 2023-12-23 20:45:39,896 - cortix - INFO - Leaching::run():time[d]=2.4
# [16418] 2023-12-23 20:45:39,998 - cortix - INFO - Leaching::run():time[d]=2.4
# [16418] 2023-12-23 20:45:40,109 - cortix - INFO - Leaching::run():time[d]=2.5
# [16418] 2023-12-23 20:45:40,217 - cortix - INFO - Leaching::run():time[d]=2.5
# [16418] 2023-12-23 20:45:40,339 - cortix - INFO - Leaching::run():time[d]=2.5
# [16418] 2023-12-23 20:45:40,454 - cortix - INFO - Leaching::run():time[d]=2.6
# [16418] 2023-12-23 20:45:40,566 - cortix - INFO - Leaching::run():time[d]=2.6
# [16418] 2023-12-23 20:45:40,675 - cortix - INFO - Leaching::run():time[d]=2.7
# [16418] 2023-12-23 20:45:40,783 - cortix - INFO - Leaching::run():time[d]=2.7
# [16418] 2023-12-23 20:45:40,888 - cortix - INFO - Leaching::run():time[d]=2.8
# [16418] 2023-12-23 20:45:41,003 - cortix - INFO - Leaching::run():time[d]=2.8
# [16418] 2023-12-23 20:45:41,108 - cortix - INFO - Leaching::run():time[d]=2.8
# [16418] 2023-12-23 20:45:41,209 - cortix - INFO - Leaching::run():time[d]=2.9
# [16418] 2023-12-23 20:45:41,341 - cortix - INFO - Leaching::run():time[d]=2.9
# [16418] 2023-12-23 20:45:41,453 - cortix - INFO - Leaching::run():time[d]=3.0
# [16418] 2023-12-23 20:45:41,560 - cortix - INFO - Leaching::run():time[d]=3.0
# [16418] 2023-12-23 20:45:41,681 - cortix - INFO - Leaching::run():time[d]=3.0
# [16418] 2023-12-23 20:45:41,815 - cortix - INFO - Leaching::run():time[d]=3.1
# [16418] 2023-12-23 20:45:41,978 - cortix - INFO - Leaching::run():time[d]=3.1
# [16418] 2023-12-23 20:45:42,101 - cortix - INFO - Leaching::run():time[d]=3.2
# [16418] 2023-12-23 20:45:42,225 - cortix - INFO - Leaching::run():time[d]=3.2
# [16418] 2023-12-23 20:45:42,367 - cortix - INFO - Leaching::run():time[d]=3.2
# [16418] 2023-12-23 20:45:42,478 - cortix - INFO - Leaching::run():time[d]=3.3
# [16418] 2023-12-23 20:45:42,589 - cortix - INFO - Leaching::run():time[d]=3.3
# [16418] 2023-12-23 20:45:42,735 - cortix - INFO - Leaching::run():time[d]=3.4
# [16418] 2023-12-23 20:45:42,879 - cortix - INFO - Leaching::run():time[d]=3.4
# [16418] 2023-12-23 20:45:43,002 - cortix - INFO - Leaching::run():time[d]=3.5
# [16418] 2023-12-23 20:45:43,111 - cortix - INFO - Leaching::run():time[d]=3.5
# [16418] 2023-12-23 20:45:43,213 - cortix - INFO - Leaching::run():time[d]=3.5
# [16418] 2023-12-23 20:45:43,341 - cortix - INFO - Leaching::run():time[d]=3.6
# [16418] 2023-12-23 20:45:43,470 - cortix - INFO - Leaching::run():time[d]=3.6
# [16418] 2023-12-23 20:45:43,598 - cortix - INFO - Leaching::run():time[d]=3.7
# [16418] 2023-12-23 20:45:43,707 - cortix - INFO - Leaching::run():time[d]=3.7
# [16418] 2023-12-23 20:45:43,854 - cortix - INFO - Leaching::run():time[d]=3.8
# [16418] 2023-12-23 20:45:43,976 - cortix - INFO - Leaching::run():time[d]=3.8
# [16418] 2023-12-23 20:45:44,130 - cortix - INFO - Leaching::run():time[d]=3.8
# [16418] 2023-12-23 20:45:44,305 - cortix - INFO - Leaching::run():time[d]=3.9
# [16418] 2023-12-23 20:45:44,421 - cortix - INFO - Leaching::run():time[d]=3.9
# [16418] 2023-12-23 20:45:44,544 - cortix - INFO - Leaching::run():time[d]=4.0
# [16418] 2023-12-23 20:45:44,672 - cortix - INFO - Leaching::run():time[d]=4.0
# [16418] 2023-12-23 20:45:44,800 - cortix - INFO - Leaching::run():time[d]=4.0
# [16418] 2023-12-23 20:45:44,932 - cortix - INFO - Leaching::run():time[d]=4.1
# [16418] 2023-12-23 20:45:45,082 - cortix - INFO - Leaching::run():time[d]=4.1
# [16418] 2023-12-23 20:45:45,199 - cortix - INFO - Leaching::run():time[d]=4.2
# [16418] 2023-12-23 20:45:45,329 - cortix - INFO - Leaching::run():time[d]=4.2
# [16418] 2023-12-23 20:45:45,448 - cortix - INFO - Leaching::run():time[d]=4.2
# [16418] 2023-12-23 20:45:45,568 - cortix - INFO - Leaching::run():time[d]=4.3
# [16418] 2023-12-23 20:45:45,700 - cortix - INFO - Leaching::run():time[d]=4.3
# [16418] 2023-12-23 20:45:45,825 - cortix - INFO - Leaching::run():time[d]=4.4
# [16418] 2023-12-23 20:45:45,955 - cortix - INFO - Leaching::run():time[d]=4.4
# [16418] 2023-12-23 20:45:46,070 - cortix - INFO - Leaching::run():time[d]=4.5
# [16418] 2023-12-23 20:45:46,215 - cortix - INFO - Leaching::run():time[d]=4.5
# [16418] 2023-12-23 20:45:46,342 - cortix - INFO - Leaching::run():time[d]=4.5
# [16418] 2023-12-23 20:45:46,458 - cortix - INFO - Leaching::run():time[d]=4.6
# [16418] 2023-12-23 20:45:46,599 - cortix - INFO - Leaching::run():time[d]=4.6
# [16418] 2023-12-23 20:45:46,728 - cortix - INFO - Leaching::run():time[d]=4.7
# [16418] 2023-12-23 20:45:46,855 - cortix - INFO - Leaching::run():time[d]=4.7
# [16418] 2023-12-23 20:45:46,977 - cortix - INFO - Leaching::run():time[d]=4.8
# [16418] 2023-12-23 20:45:47,190 - cortix - INFO - Leaching::run():time[d]=4.8
# [16418] 2023-12-23 20:45:47,313 - cortix - INFO - Leaching::run():time[d]=4.8
# [16418] 2023-12-23 20:45:47,428 - cortix - INFO - Leaching::run():time[d]=4.9
# [16418] 2023-12-23 20:45:47,543 - cortix - INFO - Leaching::run():time[d]=4.9
# [16418] 2023-12-23 20:45:47,654 - cortix - INFO - Leaching::run():time[d]=5.0
# [16418] 2023-12-23 20:45:47,751 - cortix - INFO - Leaching::run():time[d]=5.0
# [16418] 2023-12-23 20:45:47,847 - cortix - INFO - Leaching::run():time[d]=5.0
# [16418] 2023-12-23 20:45:47,962 - cortix - INFO - Leaching::run():time[d]=5.1
# [16418] 2023-12-23 20:45:48,081 - cortix - INFO - Leaching::run():time[d]=5.1
# [16418] 2023-12-23 20:45:48,221 - cortix - INFO - Leaching::run():time[d]=5.2
# [16418] 2023-12-23 20:45:48,321 - cortix - INFO - Leaching::run():time[d]=5.2
# [16418] 2023-12-23 20:45:48,441 - cortix - INFO - Leaching::run():time[d]=5.2
# [16418] 2023-12-23 20:45:48,547 - cortix - INFO - Leaching::run():time[d]=5.3
# [16418] 2023-12-23 20:45:48,640 - cortix - INFO - Leaching::run():time[d]=5.3
# [16418] 2023-12-23 20:45:48,736 - cortix - INFO - Leaching::run():time[d]=5.4
# [16418] 2023-12-23 20:45:48,855 - cortix - INFO - Leaching::run():time[d]=5.4
# [16418] 2023-12-23 20:45:48,978 - cortix - INFO - Leaching::run():time[d]=5.5
# [16418] 2023-12-23 20:45:49,075 - cortix - INFO - Leaching::run():time[d]=5.5
# [16418] 2023-12-23 20:45:49,177 - cortix - INFO - Leaching::run():time[d]=5.5
# [16418] 2023-12-23 20:45:49,287 - cortix - INFO - Leaching::run():time[d]=5.6
# [16418] 2023-12-23 20:45:49,394 - cortix - INFO - Leaching::run():time[d]=5.6
# [16418] 2023-12-23 20:45:49,488 - cortix - INFO - Leaching::run():time[d]=5.7
# [16418] 2023-12-23 20:45:49,587 - cortix - INFO - Leaching::run():time[d]=5.7
# [16418] 2023-12-23 20:45:49,688 - cortix - INFO - Leaching::run():time[d]=5.8
# [16418] 2023-12-23 20:45:49,804 - cortix - INFO - Leaching::run():time[d]=5.8
# [16418] 2023-12-23 20:45:49,916 - cortix - INFO - Leaching::run():time[d]=5.8
# [16418] 2023-12-23 20:45:50,017 - cortix - INFO - Leaching::run():time[d]=5.9
# [16418] 2023-12-23 20:45:50,131 - cortix - INFO - Leaching::run():time[d]=5.9
# [16418] 2023-12-23 20:45:50,238 - cortix - INFO - Leaching::run():time[d]=6.0
# [16418] 2023-12-23 20:45:50,333 - cortix - INFO - Leaching::run():time[d]=6.0
# [16418] 2023-12-23 20:45:50,440 - cortix - INFO - Leaching::run():time[d]=6.0
# [16418] 2023-12-23 20:45:50,547 - cortix - INFO - Leaching::run():time[d]=6.1
# [16418] 2023-12-23 20:45:50,644 - cortix - INFO - Leaching::run():time[d]=6.1
# [16418] 2023-12-23 20:45:50,754 - cortix - INFO - Leaching::run():time[d]=6.2
# [16418] 2023-12-23 20:45:50,860 - cortix - INFO - Leaching::run():time[d]=6.2
# [16418] 2023-12-23 20:45:51,003 - cortix - INFO - Leaching::run():time[d]=6.2
# [16418] 2023-12-23 20:45:51,165 - cortix - INFO - Leaching::run():time[d]=6.3
# [16418] 2023-12-23 20:45:51,277 - cortix - INFO - Leaching::run():time[d]=6.3
# [16418] 2023-12-23 20:45:51,380 - cortix - INFO - Leaching::run():time[d]=6.4
# [16418] 2023-12-23 20:45:51,492 - cortix - INFO - Leaching::run():time[d]=6.4
# [16418] 2023-12-23 20:45:51,600 - cortix - INFO - Leaching::run():time[d]=6.5
# [16418] 2023-12-23 20:45:51,713 - cortix - INFO - Leaching::run():time[d]=6.5
# [16418] 2023-12-23 20:45:51,825 - cortix - INFO - Leaching::run():time[d]=6.5
# [16418] 2023-12-23 20:45:51,938 - cortix - INFO - Leaching::run():time[d]=6.6
# [16418] 2023-12-23 20:45:52,075 - cortix - INFO - Leaching::run():time[d]=6.6
# [16418] 2023-12-23 20:45:52,178 - cortix - INFO - Leaching::run():time[d]=6.7
# [16418] 2023-12-23 20:45:52,278 - cortix - INFO - Leaching::run():time[d]=6.7
# [16418] 2023-12-23 20:45:52,395 - cortix - INFO - Leaching::run():time[d]=6.8
# [16418] 2023-12-23 20:45:52,482 - cortix - INFO - Leaching::run():time[d]=6.8
# [16418] 2023-12-23 20:45:52,570 - cortix - INFO - Leaching::run():time[d]=6.8
# [16418] 2023-12-23 20:45:52,665 - cortix - INFO - Leaching::run():time[d]=6.9
# [16418] 2023-12-23 20:45:52,771 - cortix - INFO - Leaching::run():time[d]=6.9
# [16418] 2023-12-23 20:45:52,913 - cortix - INFO - Leaching::run():time[d]=7.0
# [16418] 2023-12-23 20:45:53,055 - cortix - INFO - Leaching::run():time[d]=7.0
# [16418] 2023-12-23 20:45:53,163 - cortix - INFO - Leaching::run():time[d]=7.0
# [16418] 2023-12-23 20:45:53,262 - cortix - INFO - Leaching::run():time[d]=7.1
# [16418] 2023-12-23 20:45:53,360 - cortix - INFO - Leaching::run():time[d]=7.1
# [16418] 2023-12-23 20:45:53,473 - cortix - INFO - Leaching::run():time[d]=7.2
# [16418] 2023-12-23 20:45:53,580 - cortix - INFO - Leaching::run():time[d]=7.2
# [16418] 2023-12-23 20:45:53,682 - cortix - INFO - Leaching::run():time[d]=7.2
# [16418] 2023-12-23 20:45:53,798 - cortix - INFO - Leaching::run():time[d]=7.3
# [16418] 2023-12-23 20:45:53,907 - cortix - INFO - Leaching::run():time[d]=7.3
# [16418] 2023-12-23 20:45:54,037 - cortix - INFO - Leaching::run():time[d]=7.4
# [16418] 2023-12-23 20:45:54,181 - cortix - INFO - Leaching::run():time[d]=7.4
# [16418] 2023-12-23 20:45:54,327 - cortix - INFO - Leaching::run():time[d]=7.5
# [16418] 2023-12-23 20:45:54,461 - cortix - INFO - Leaching::run():time[d]=7.5
# [16418] 2023-12-23 20:45:54,618 - cortix - INFO - Leaching::run():time[d]=7.5
# [16418] 2023-12-23 20:45:54,734 - cortix - INFO - Leaching::run():time[d]=7.6
# [16418] 2023-12-23 20:45:54,863 - cortix - INFO - Leaching::run():time[d]=7.6
# [16418] 2023-12-23 20:45:54,965 - cortix - INFO - Leaching::run():time[d]=7.7
# [16418] 2023-12-23 20:45:55,105 - cortix - INFO - Leaching::run():time[d]=7.7
# [16418] 2023-12-23 20:45:55,261 - cortix - INFO - Leaching::run():time[d]=7.8
# [16418] 2023-12-23 20:45:55,420 - cortix - INFO - Leaching::run():time[d]=7.8
# [16418] 2023-12-23 20:45:55,538 - cortix - INFO - Leaching::run():time[d]=7.8
# [16418] 2023-12-23 20:45:55,652 - cortix - INFO - Leaching::run():time[d]=7.9
# [16418] 2023-12-23 20:45:55,759 - cortix - INFO - Leaching::run():time[d]=7.9
# [16418] 2023-12-23 20:45:55,857 - cortix - INFO - Leaching::run():time[d]=8.0
# [16418] 2023-12-23 20:45:55,975 - cortix - INFO - Leaching::run():time[d]=8.0
# [16418] 2023-12-23 20:45:56,074 - cortix - INFO - Leaching::run():time[d]=8.0
# [16418] 2023-12-23 20:45:56,177 - cortix - INFO - Leaching::run():time[d]=8.1
# [16418] 2023-12-23 20:45:56,302 - cortix - INFO - Leaching::run():time[d]=8.1
# [16418] 2023-12-23 20:45:56,426 - cortix - INFO - Leaching::run():time[d]=8.2
# [16418] 2023-12-23 20:45:56,545 - cortix - INFO - Leaching::run():time[d]=8.2
# [16418] 2023-12-23 20:45:56,663 - cortix - INFO - Leaching::run():time[d]=8.2
# [16418] 2023-12-23 20:45:56,788 - cortix - INFO - Leaching::run():time[d]=8.3
# [16418] 2023-12-23 20:45:56,911 - cortix - INFO - Leaching::run():time[d]=8.3
# [16418] 2023-12-23 20:45:57,083 - cortix - INFO - Leaching::run():time[d]=8.4
# [16418] 2023-12-23 20:45:57,238 - cortix - INFO - Leaching::run():time[d]=8.4
# [16418] 2023-12-23 20:45:57,388 - cortix - INFO - Leaching::run():time[d]=8.5
# [16418] 2023-12-23 20:45:57,523 - cortix - INFO - Leaching::run():time[d]=8.5
# [16418] 2023-12-23 20:45:57,668 - cortix - INFO - Leaching::run():time[d]=8.5
# [16418] 2023-12-23 20:45:57,816 - cortix - INFO - Leaching::run():time[d]=8.6
# [16418] 2023-12-23 20:45:57,984 - cortix - INFO - Leaching::run():time[d]=8.6
# [16418] 2023-12-23 20:45:58,091 - cortix - INFO - Leaching::run():time[d]=8.7
# [16418] 2023-12-23 20:45:58,184 - cortix - INFO - Leaching::run():time[d]=8.7
# [16418] 2023-12-23 20:45:58,282 - cortix - INFO - Leaching::run():time[d]=8.8
# [16418] 2023-12-23 20:45:58,380 - cortix - INFO - Leaching::run():time[d]=8.8
# [16418] 2023-12-23 20:45:58,492 - cortix - INFO - Leaching::run():time[d]=8.8
# [16418] 2023-12-23 20:45:58,606 - cortix - INFO - Leaching::run():time[d]=8.9
# [16418] 2023-12-23 20:45:58,713 - cortix - INFO - Leaching::run():time[d]=8.9
# [16418] 2023-12-23 20:45:58,810 - cortix - INFO - Leaching::run():time[d]=9.0
# [16418] 2023-12-23 20:45:58,915 - cortix - INFO - Leaching::run():time[d]=9.0
# [16418] 2023-12-23 20:45:59,027 - cortix - INFO - Leaching::run():time[d]=9.0
# [16418] 2023-12-23 20:45:59,126 - cortix - INFO - Leaching::run():time[d]=9.1
# [16418] 2023-12-23 20:45:59,230 - cortix - INFO - Leaching::run():time[d]=9.1
# [16418] 2023-12-23 20:45:59,355 - cortix - INFO - Leaching::run():time[d]=9.2
# [16418] 2023-12-23 20:45:59,496 - cortix - INFO - Leaching::run():time[d]=9.2
# [16418] 2023-12-23 20:45:59,609 - cortix - INFO - Leaching::run():time[d]=9.2
# [16418] 2023-12-23 20:45:59,723 - cortix - INFO - Leaching::run():time[d]=9.3
# [16418] 2023-12-23 20:45:59,830 - cortix - INFO - Leaching::run():time[d]=9.3
# [16418] 2023-12-23 20:46:00,041 - cortix - INFO - Leaching::run():time[d]=9.4
# [16418] 2023-12-23 20:46:00,244 - cortix - INFO - Leaching::run():time[d]=9.4
# [16418] 2023-12-23 20:46:00,447 - cortix - INFO - Leaching::run():time[d]=9.5
# [16418] 2023-12-23 20:46:00,724 - cortix - INFO - Leaching::run():time[d]=9.5
# [16418] 2023-12-23 20:46:00,981 - cortix - INFO - Leaching::run():time[d]=9.5
# [16418] 2023-12-23 20:46:01,085 - cortix - INFO - Leaching::run():time[d]=9.6
# [16418] 2023-12-23 20:46:01,214 - cortix - INFO - Leaching::run():time[d]=9.6
# [16418] 2023-12-23 20:46:01,318 - cortix - INFO - Leaching::run():time[d]=9.7
# [16418] 2023-12-23 20:46:01,425 - cortix - INFO - Leaching::run():time[d]=9.7
# [16418] 2023-12-23 20:46:01,541 - cortix - INFO - Leaching::run():time[d]=9.8
# [16418] 2023-12-23 20:46:01,653 - cortix - INFO - Leaching::run():time[d]=9.8
# [16418] 2023-12-23 20:46:01,771 - cortix - INFO - Leaching::run():time[d]=9.8
# [16418] 2023-12-23 20:46:01,997 - cortix - INFO - Leaching::run():time[d]=9.9
# [16418] 2023-12-23 20:46:02,215 - cortix - INFO - Leaching::run():time[d]=9.9
# [16418] 2023-12-23 20:46:02,437 - cortix - INFO - Leaching::run():time[d]=10.0
# [16418] 2023-12-23 20:46:02,676 - cortix - INFO - Leaching::run():time[d]=10.0
# [16418] 2023-12-23 20:46:02,749 - cortix - INFO - run()::Elapsed wall clock time [s]: 29.45
# [16418] 2023-12-23 20:46:02,757 - cortix - INFO - Closed Cortix object.
# _____________________________________________________________________________
#                            T E R M I N A T I N G
# _____________________________________________________________________________
#       ...                                        s       .     (TAAG Fraktur)
#    xH88"`~ .x8X                                 :8      @88>
#  :8888   .f"8888Hf        u.      .u    .      .88      %8P      uL   ..
# :8888>  X8L  ^""`   ...ue888b   .d88B :@8c    :888ooo    .     .@88b  @88R
# X8888  X888h        888R Y888r ="8888f8888r -*8888888  .@88u  ""Y888k/"*P
# 88888  !88888.      888R I888>   4888>"88"    8888    888E`    Y888L
# 88888   %88888      888R I888>   4888> "      8888      888E      8888
# 88888 `> `8888>     888R I888>   4888>        8888      888E      `888N
# `8888L %  ?888   ! u8888cJ888   .d888L .+    .8888Lu=   888E   .u./"888&
#  `8888  `-*""   /   "*888*P"    ^"8888*"     ^%888*     888&  d888" Y888*"
#    "888.      :"      "Y"          "Y"         "Y"      R888" ` "Y   Y"
#      `""***~"`                                           ""
#                              https://cortix.org
# _____________________________________________________________________________
# [16418] 2023-12-23 20:46:02,776 - cortix - INFO - close()::Elapsed wall clock time [s]: 29.48

# %%
'''Recover modules data'''
leaching = wm_net.modules[0]

# %%
'''Leaching data'''
leaching.preleach_phase.plot(['liquid-volume','mass-flowrate','mass-density'],show=True,figsize=[14,8])
leaching.acidleach_phase.plot(['liquid-volume','mass-flowrate','mass-density'],show=True,figsize=[14,8])

# %% [markdown]
# ## [References](#toc)<a id="refs"></a>
