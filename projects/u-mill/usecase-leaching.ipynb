# %% [markdown]
# **Engy-4390** Nuclear Systems Design and Analysis, UMass Lowell, Chem. Eng. Nuclear Program Fall 2023
#
# # Uranium Mill Network Dynamics Simulation
# $
#   \newcommand{\Amtrx}{\boldsymbol{\mathsf{A}}}
#   \newcommand{\Bmtrx}{\boldsymbol{\mathsf{B}}}
#   \newcommand{\Mmtrx}{\boldsymbol{\mathsf{M}}}
#   \newcommand{\Imtrx}{\boldsymbol{\mathsf{I}}}
#   \newcommand{\Pmtrx}{\boldsymbol{\mathsf{P}}}
#   \newcommand{\Lmtrx}{\boldsymbol{\mathsf{L}}}
#   \newcommand{\Umtrx}{\boldsymbol{\mathsf{U}}}
#   \newcommand{\Smtrx}{\boldsymbol{\mathsf{S}}}
#   \newcommand{\xvec}{\boldsymbol{\mathsf{x}}}
#   \newcommand{\uvar}{\boldsymbol{u}}
#   \newcommand{\fvar}{\boldsymbol{f}}
#   \newcommand{\avec}{\boldsymbol{\mathsf{a}}}
#   \newcommand{\bvec}{\boldsymbol{\mathsf{b}}}
#   \newcommand{\cvec}{\boldsymbol{\mathsf{c}}}
#   \newcommand{\rvec}{\boldsymbol{\mathsf{r}}}
#   \newcommand{\mvec}{\boldsymbol{\mathsf{m}}}
#   \newcommand{\gvec}{\boldsymbol{\mathsf{g}}}
#   \newcommand{\zerovec}{\boldsymbol{\mathsf{0}}}
#   \newcommand{\norm}[1]{\bigl\lVert{#1}\bigr\rVert}
#   \newcommand{\transpose}[1]{{#1}^\top}
#   \DeclareMathOperator{\rank}{rank}
#   \newcommand{\Power}{\mathcal{P}}
# $

# %% [markdown]
# ## Stand-Alone Leaching Module
# In construction...<br>
# [Project Repository on `GitHub`](https://github.com/dpploy/engy-4390/tree/main/projects/u-mill)

# %% [markdown]
# ---
# ## Table of Contents<a id="toc"></a>
# * [Objectives](#obj)
# * [References](#refs)
# ---

# %% [markdown]
# ## [Objectives](#toc)<a id="obj"></a>

# %% [markdown]
# - Test the implementation of coupled modules in Cortix.
# - Present an executable environment for learning how to use the Cortix modules developed for a simplified Whit Mesa Milling flowsheet.

# %%
'''Setup a White Mesa plant'''
from cortix import Cortix
from cortix import Network
import unit
white_mesa = Cortix(use_mpi=False, splash=True) # System top level
wm_net = white_mesa.network = Network() # Network
# Out:
# [24431] 2023-12-23 03:34:58,502 - cortix - INFO - Created Cortix object
# _____________________________________________________________________________
#                              L A U N C H I N G
# _____________________________________________________________________________
#       ...                                        s       .     (TAAG Fraktur)
#    xH88"`~ .x8X                                 :8      @88>
#  :8888   .f"8888Hf        u.      .u    .      .88      %8P      uL   ..
# :8888>  X8L  ^""`   ...ue888b   .d88B :@8c    :888ooo    .     .@88b  @88R
# X8888  X888h        888R Y888r ="8888f8888r -*8888888  .@88u  ""Y888k/"*P
# 88888  !88888.      888R I888>   4888>"88"    8888    888E`    Y888L
# 88888   %88888      888R I888>   4888> "      8888      888E      8888
# 88888 `> `8888>     888R I888>   4888>        8888      888E      `888N
# `8888L %  ?888   ! u8888cJ888   .d888L .+    .8888Lu=   888E   .u./"888&
#  `8888  `-*""   /   "*888*P"    ^"8888*"     ^%888*     888&  d888" Y888*"
#    "888.      :"      "Y"          "Y"         "Y"      R888" ` "Y   Y"
#      `""***~"`                                           ""
#                              https://cortix.org
# _____________________________________________________________________________

# %%
'''Setup Leaching'''
from white_mesa.leaching import Leaching 
leaching = Leaching()
wm_net.module(leaching)

# %%
'''Setup Network'''
wm_net.draw(engine='dot', node_shape='folder', size='600,1200')

# %%
'''Initialize run'''
end_time = 10*unit.day
time_step = 10.0*unit.minute
show_time = (True, unit.hour)

leaching.end_time = end_time
leaching.time_step = time_step
leaching.show_time = show_time

# %%
'''Run White Mesa and shutdown'''   
white_mesa.run()
white_mesa.close()
# Out:
# [24431] 2023-12-23 03:34:58,826 - cortix - INFO - Launching Module <white_mesa.leaching.Leaching object at 0x7fd61be8a2d0>
# [24431] 2023-12-23 03:34:58,833 - cortix - INFO - Leaching::run():time[d]=0.0
# [24431] 2023-12-23 03:34:58,939 - cortix - INFO - Leaching::run():time[d]=0.0
# [24431] 2023-12-23 03:34:59,027 - cortix - INFO - Leaching::run():time[d]=0.1
# [24431] 2023-12-23 03:34:59,115 - cortix - INFO - Leaching::run():time[d]=0.1
# [24431] 2023-12-23 03:34:59,203 - cortix - INFO - Leaching::run():time[d]=0.2
# [24431] 2023-12-23 03:34:59,292 - cortix - INFO - Leaching::run():time[d]=0.2
# [24431] 2023-12-23 03:34:59,382 - cortix - INFO - Leaching::run():time[d]=0.2
# [24431] 2023-12-23 03:34:59,473 - cortix - INFO - Leaching::run():time[d]=0.3
# [24431] 2023-12-23 03:34:59,562 - cortix - INFO - Leaching::run():time[d]=0.3
# [24431] 2023-12-23 03:34:59,650 - cortix - INFO - Leaching::run():time[d]=0.4
# [24431] 2023-12-23 03:34:59,738 - cortix - INFO - Leaching::run():time[d]=0.4
# [24431] 2023-12-23 03:34:59,826 - cortix - INFO - Leaching::run():time[d]=0.5
# [24431] 2023-12-23 03:34:59,915 - cortix - INFO - Leaching::run():time[d]=0.5
# [24431] 2023-12-23 03:35:00,005 - cortix - INFO - Leaching::run():time[d]=0.5
# [24431] 2023-12-23 03:35:00,093 - cortix - INFO - Leaching::run():time[d]=0.6
# [24431] 2023-12-23 03:35:00,181 - cortix - INFO - Leaching::run():time[d]=0.6
# [24431] 2023-12-23 03:35:00,269 - cortix - INFO - Leaching::run():time[d]=0.7
# [24431] 2023-12-23 03:35:00,359 - cortix - INFO - Leaching::run():time[d]=0.7
# [24431] 2023-12-23 03:35:00,450 - cortix - INFO - Leaching::run():time[d]=0.8
# [24431] 2023-12-23 03:35:00,538 - cortix - INFO - Leaching::run():time[d]=0.8
# [24431] 2023-12-23 03:35:00,624 - cortix - INFO - Leaching::run():time[d]=0.8
# [24431] 2023-12-23 03:35:00,710 - cortix - INFO - Leaching::run():time[d]=0.9
# [24431] 2023-12-23 03:35:00,797 - cortix - INFO - Leaching::run():time[d]=0.9
# [24431] 2023-12-23 03:35:00,883 - cortix - INFO - Leaching::run():time[d]=1.0
# [24431] 2023-12-23 03:35:00,970 - cortix - INFO - Leaching::run():time[d]=1.0
# [24431] 2023-12-23 03:35:01,060 - cortix - INFO - Leaching::run():time[d]=1.0
# [24431] 2023-12-23 03:35:01,149 - cortix - INFO - Leaching::run():time[d]=1.1
# [24431] 2023-12-23 03:35:01,237 - cortix - INFO - Leaching::run():time[d]=1.1
# [24431] 2023-12-23 03:35:01,327 - cortix - INFO - Leaching::run():time[d]=1.2
# [24431] 2023-12-23 03:35:01,416 - cortix - INFO - Leaching::run():time[d]=1.2
# [24431] 2023-12-23 03:35:01,504 - cortix - INFO - Leaching::run():time[d]=1.2
# [24431] 2023-12-23 03:35:01,592 - cortix - INFO - Leaching::run():time[d]=1.3
# [24431] 2023-12-23 03:35:01,680 - cortix - INFO - Leaching::run():time[d]=1.3
# [24431] 2023-12-23 03:35:01,770 - cortix - INFO - Leaching::run():time[d]=1.4
# [24431] 2023-12-23 03:35:01,851 - cortix - INFO - Leaching::run():time[d]=1.4
# [24431] 2023-12-23 03:35:01,940 - cortix - INFO - Leaching::run():time[d]=1.5
# [24431] 2023-12-23 03:35:02,036 - cortix - INFO - Leaching::run():time[d]=1.5
# [24431] 2023-12-23 03:35:02,133 - cortix - INFO - Leaching::run():time[d]=1.5
# [24431] 2023-12-23 03:35:02,228 - cortix - INFO - Leaching::run():time[d]=1.6
# [24431] 2023-12-23 03:35:02,326 - cortix - INFO - Leaching::run():time[d]=1.6
# [24431] 2023-12-23 03:35:02,417 - cortix - INFO - Leaching::run():time[d]=1.7
# [24431] 2023-12-23 03:35:02,506 - cortix - INFO - Leaching::run():time[d]=1.7
# [24431] 2023-12-23 03:35:02,596 - cortix - INFO - Leaching::run():time[d]=1.8
# [24431] 2023-12-23 03:35:02,677 - cortix - INFO - Leaching::run():time[d]=1.8
# [24431] 2023-12-23 03:35:02,760 - cortix - INFO - Leaching::run():time[d]=1.8
# [24431] 2023-12-23 03:35:02,843 - cortix - INFO - Leaching::run():time[d]=1.9
# [24431] 2023-12-23 03:35:02,925 - cortix - INFO - Leaching::run():time[d]=1.9
# [24431] 2023-12-23 03:35:03,009 - cortix - INFO - Leaching::run():time[d]=2.0
# [24431] 2023-12-23 03:35:03,093 - cortix - INFO - Leaching::run():time[d]=2.0
# [24431] 2023-12-23 03:35:03,177 - cortix - INFO - Leaching::run():time[d]=2.0
# [24431] 2023-12-23 03:35:03,263 - cortix - INFO - Leaching::run():time[d]=2.1
# [24431] 2023-12-23 03:35:03,353 - cortix - INFO - Leaching::run():time[d]=2.1
# [24431] 2023-12-23 03:35:03,444 - cortix - INFO - Leaching::run():time[d]=2.2
# [24431] 2023-12-23 03:35:03,531 - cortix - INFO - Leaching::run():time[d]=2.2
# [24431] 2023-12-23 03:35:03,617 - cortix - INFO - Leaching::run():time[d]=2.2
# [24431] 2023-12-23 03:35:03,704 - cortix - INFO - Leaching::run():time[d]=2.3
# [24431] 2023-12-23 03:35:03,790 - cortix - INFO - Leaching::run():time[d]=2.3
# [24431] 2023-12-23 03:35:03,877 - cortix - INFO - Leaching::run():time[d]=2.4
# [24431] 2023-12-23 03:35:03,962 - cortix - INFO - Leaching::run():time[d]=2.4
# [24431] 2023-12-23 03:35:04,049 - cortix - INFO - Leaching::run():time[d]=2.5
# [24431] 2023-12-23 03:35:04,134 - cortix - INFO - Leaching::run():time[d]=2.5
# [24431] 2023-12-23 03:35:04,219 - cortix - INFO - Leaching::run():time[d]=2.5
# [24431] 2023-12-23 03:35:04,306 - cortix - INFO - Leaching::run():time[d]=2.6
# [24431] 2023-12-23 03:35:04,393 - cortix - INFO - Leaching::run():time[d]=2.6
# [24431] 2023-12-23 03:35:04,481 - cortix - INFO - Leaching::run():time[d]=2.7
# [24431] 2023-12-23 03:35:04,571 - cortix - INFO - Leaching::run():time[d]=2.7
# [24431] 2023-12-23 03:35:04,657 - cortix - INFO - Leaching::run():time[d]=2.8
# [24431] 2023-12-23 03:35:04,743 - cortix - INFO - Leaching::run():time[d]=2.8
# [24431] 2023-12-23 03:35:04,828 - cortix - INFO - Leaching::run():time[d]=2.8
# [24431] 2023-12-23 03:35:04,914 - cortix - INFO - Leaching::run():time[d]=2.9
# [24431] 2023-12-23 03:35:05,002 - cortix - INFO - Leaching::run():time[d]=2.9
# [24431] 2023-12-23 03:35:05,088 - cortix - INFO - Leaching::run():time[d]=3.0
# [24431] 2023-12-23 03:35:05,172 - cortix - INFO - Leaching::run():time[d]=3.0
# [24431] 2023-12-23 03:35:05,254 - cortix - INFO - Leaching::run():time[d]=3.0
# [24431] 2023-12-23 03:35:05,345 - cortix - INFO - Leaching::run():time[d]=3.1
# [24431] 2023-12-23 03:35:05,436 - cortix - INFO - Leaching::run():time[d]=3.1
# [24431] 2023-12-23 03:35:05,526 - cortix - INFO - Leaching::run():time[d]=3.2
# [24431] 2023-12-23 03:35:05,616 - cortix - INFO - Leaching::run():time[d]=3.2
# [24431] 2023-12-23 03:35:05,705 - cortix - INFO - Leaching::run():time[d]=3.2
# [24431] 2023-12-23 03:35:05,796 - cortix - INFO - Leaching::run():time[d]=3.3
# [24431] 2023-12-23 03:35:05,886 - cortix - INFO - Leaching::run():time[d]=3.3
# [24431] 2023-12-23 03:35:05,976 - cortix - INFO - Leaching::run():time[d]=3.4
# [24431] 2023-12-23 03:35:06,066 - cortix - INFO - Leaching::run():time[d]=3.4
# [24431] 2023-12-23 03:35:06,156 - cortix - INFO - Leaching::run():time[d]=3.5
# [24431] 2023-12-23 03:35:06,246 - cortix - INFO - Leaching::run():time[d]=3.5
# [24431] 2023-12-23 03:35:06,336 - cortix - INFO - Leaching::run():time[d]=3.5
# [24431] 2023-12-23 03:35:06,427 - cortix - INFO - Leaching::run():time[d]=3.6
# [24431] 2023-12-23 03:35:06,511 - cortix - INFO - Leaching::run():time[d]=3.6
# [24431] 2023-12-23 03:35:06,594 - cortix - INFO - Leaching::run():time[d]=3.7
# [24431] 2023-12-23 03:35:06,678 - cortix - INFO - Leaching::run():time[d]=3.7
# [24431] 2023-12-23 03:35:06,764 - cortix - INFO - Leaching::run():time[d]=3.8
# [24431] 2023-12-23 03:35:06,851 - cortix - INFO - Leaching::run():time[d]=3.8
# [24431] 2023-12-23 03:35:06,937 - cortix - INFO - Leaching::run():time[d]=3.8
# [24431] 2023-12-23 03:35:07,026 - cortix - INFO - Leaching::run():time[d]=3.9
# [24431] 2023-12-23 03:35:07,113 - cortix - INFO - Leaching::run():time[d]=3.9
# [24431] 2023-12-23 03:35:07,201 - cortix - INFO - Leaching::run():time[d]=4.0
# [24431] 2023-12-23 03:35:07,288 - cortix - INFO - Leaching::run():time[d]=4.0
# [24431] 2023-12-23 03:35:07,372 - cortix - INFO - Leaching::run():time[d]=4.0
# [24431] 2023-12-23 03:35:07,460 - cortix - INFO - Leaching::run():time[d]=4.1
# [24431] 2023-12-23 03:35:07,549 - cortix - INFO - Leaching::run():time[d]=4.1
# [24431] 2023-12-23 03:35:07,637 - cortix - INFO - Leaching::run():time[d]=4.2
# [24431] 2023-12-23 03:35:07,725 - cortix - INFO - Leaching::run():time[d]=4.2
# [24431] 2023-12-23 03:35:07,813 - cortix - INFO - Leaching::run():time[d]=4.2
# [24431] 2023-12-23 03:35:07,901 - cortix - INFO - Leaching::run():time[d]=4.3
# [24431] 2023-12-23 03:35:07,989 - cortix - INFO - Leaching::run():time[d]=4.3
# [24431] 2023-12-23 03:35:08,073 - cortix - INFO - Leaching::run():time[d]=4.4
# [24431] 2023-12-23 03:35:08,158 - cortix - INFO - Leaching::run():time[d]=4.4
# [24431] 2023-12-23 03:35:08,243 - cortix - INFO - Leaching::run():time[d]=4.5
# [24431] 2023-12-23 03:35:08,328 - cortix - INFO - Leaching::run():time[d]=4.5
# [24431] 2023-12-23 03:35:08,415 - cortix - INFO - Leaching::run():time[d]=4.5
# [24431] 2023-12-23 03:35:08,501 - cortix - INFO - Leaching::run():time[d]=4.6
# [24431] 2023-12-23 03:35:08,587 - cortix - INFO - Leaching::run():time[d]=4.6
# [24431] 2023-12-23 03:35:08,671 - cortix - INFO - Leaching::run():time[d]=4.7
# [24431] 2023-12-23 03:35:08,754 - cortix - INFO - Leaching::run():time[d]=4.7
# [24431] 2023-12-23 03:35:08,838 - cortix - INFO - Leaching::run():time[d]=4.8
# [24431] 2023-12-23 03:35:08,922 - cortix - INFO - Leaching::run():time[d]=4.8
# [24431] 2023-12-23 03:35:09,008 - cortix - INFO - Leaching::run():time[d]=4.8
# [24431] 2023-12-23 03:35:09,094 - cortix - INFO - Leaching::run():time[d]=4.9
# [24431] 2023-12-23 03:35:09,181 - cortix - INFO - Leaching::run():time[d]=4.9
# [24431] 2023-12-23 03:35:09,267 - cortix - INFO - Leaching::run():time[d]=5.0
# [24431] 2023-12-23 03:35:09,354 - cortix - INFO - Leaching::run():time[d]=5.0
# [24431] 2023-12-23 03:35:09,443 - cortix - INFO - Leaching::run():time[d]=5.0
# [24431] 2023-12-23 03:35:09,529 - cortix - INFO - Leaching::run():time[d]=5.1
# [24431] 2023-12-23 03:35:09,616 - cortix - INFO - Leaching::run():time[d]=5.1
# [24431] 2023-12-23 03:35:09,703 - cortix - INFO - Leaching::run():time[d]=5.2
# [24431] 2023-12-23 03:35:09,789 - cortix - INFO - Leaching::run():time[d]=5.2
# [24431] 2023-12-23 03:35:09,875 - cortix - INFO - Leaching::run():time[d]=5.2
# [24431] 2023-12-23 03:35:09,961 - cortix - INFO - Leaching::run():time[d]=5.3
# [24431] 2023-12-23 03:35:10,048 - cortix - INFO - Leaching::run():time[d]=5.3
# [24431] 2023-12-23 03:35:10,134 - cortix - INFO - Leaching::run():time[d]=5.4
# [24431] 2023-12-23 03:35:10,220 - cortix - INFO - Leaching::run():time[d]=5.4
# [24431] 2023-12-23 03:35:10,307 - cortix - INFO - Leaching::run():time[d]=5.5
# [24431] 2023-12-23 03:35:10,393 - cortix - INFO - Leaching::run():time[d]=5.5
# [24431] 2023-12-23 03:35:10,481 - cortix - INFO - Leaching::run():time[d]=5.5
# [24431] 2023-12-23 03:35:10,567 - cortix - INFO - Leaching::run():time[d]=5.6
# [24431] 2023-12-23 03:35:10,652 - cortix - INFO - Leaching::run():time[d]=5.6
# [24431] 2023-12-23 03:35:10,736 - cortix - INFO - Leaching::run():time[d]=5.7
# [24431] 2023-12-23 03:35:10,819 - cortix - INFO - Leaching::run():time[d]=5.7
# [24431] 2023-12-23 03:35:10,905 - cortix - INFO - Leaching::run():time[d]=5.8
# [24431] 2023-12-23 03:35:10,991 - cortix - INFO - Leaching::run():time[d]=5.8
# [24431] 2023-12-23 03:35:11,076 - cortix - INFO - Leaching::run():time[d]=5.8
# [24431] 2023-12-23 03:35:11,163 - cortix - INFO - Leaching::run():time[d]=5.9
# [24431] 2023-12-23 03:35:11,251 - cortix - INFO - Leaching::run():time[d]=5.9
# [24431] 2023-12-23 03:35:11,340 - cortix - INFO - Leaching::run():time[d]=6.0
# [24431] 2023-12-23 03:35:11,428 - cortix - INFO - Leaching::run():time[d]=6.0
# [24431] 2023-12-23 03:35:11,520 - cortix - INFO - Leaching::run():time[d]=6.0
# [24431] 2023-12-23 03:35:11,614 - cortix - INFO - Leaching::run():time[d]=6.1
# [24431] 2023-12-23 03:35:11,710 - cortix - INFO - Leaching::run():time[d]=6.1
# [24431] 2023-12-23 03:35:11,803 - cortix - INFO - Leaching::run():time[d]=6.2
# [24431] 2023-12-23 03:35:11,894 - cortix - INFO - Leaching::run():time[d]=6.2
# [24431] 2023-12-23 03:35:11,988 - cortix - INFO - Leaching::run():time[d]=6.2
# [24431] 2023-12-23 03:35:12,083 - cortix - INFO - Leaching::run():time[d]=6.3
# [24431] 2023-12-23 03:35:12,178 - cortix - INFO - Leaching::run():time[d]=6.3
# [24431] 2023-12-23 03:35:12,271 - cortix - INFO - Leaching::run():time[d]=6.4
# [24431] 2023-12-23 03:35:12,364 - cortix - INFO - Leaching::run():time[d]=6.4
# [24431] 2023-12-23 03:35:12,460 - cortix - INFO - Leaching::run():time[d]=6.5
# [24431] 2023-12-23 03:35:12,550 - cortix - INFO - Leaching::run():time[d]=6.5
# [24431] 2023-12-23 03:35:12,647 - cortix - INFO - Leaching::run():time[d]=6.5
# [24431] 2023-12-23 03:35:12,755 - cortix - INFO - Leaching::run():time[d]=6.6
# [24431] 2023-12-23 03:35:12,867 - cortix - INFO - Leaching::run():time[d]=6.6
# [24431] 2023-12-23 03:35:12,960 - cortix - INFO - Leaching::run():time[d]=6.7
# [24431] 2023-12-23 03:35:13,051 - cortix - INFO - Leaching::run():time[d]=6.7
# [24431] 2023-12-23 03:35:13,159 - cortix - INFO - Leaching::run():time[d]=6.8
# [24431] 2023-12-23 03:35:13,257 - cortix - INFO - Leaching::run():time[d]=6.8
# [24431] 2023-12-23 03:35:13,346 - cortix - INFO - Leaching::run():time[d]=6.8
# [24431] 2023-12-23 03:35:13,446 - cortix - INFO - Leaching::run():time[d]=6.9
# [24431] 2023-12-23 03:35:13,551 - cortix - INFO - Leaching::run():time[d]=6.9
# [24431] 2023-12-23 03:35:13,641 - cortix - INFO - Leaching::run():time[d]=7.0
# [24431] 2023-12-23 03:35:13,743 - cortix - INFO - Leaching::run():time[d]=7.0
# [24431] 2023-12-23 03:35:13,850 - cortix - INFO - Leaching::run():time[d]=7.0
# [24431] 2023-12-23 03:35:13,949 - cortix - INFO - Leaching::run():time[d]=7.1
# [24431] 2023-12-23 03:35:14,048 - cortix - INFO - Leaching::run():time[d]=7.1
# [24431] 2023-12-23 03:35:14,151 - cortix - INFO - Leaching::run():time[d]=7.2
# [24431] 2023-12-23 03:35:14,244 - cortix - INFO - Leaching::run():time[d]=7.2
# [24431] 2023-12-23 03:35:14,344 - cortix - INFO - Leaching::run():time[d]=7.2
# [24431] 2023-12-23 03:35:14,445 - cortix - INFO - Leaching::run():time[d]=7.3
# [24431] 2023-12-23 03:35:14,539 - cortix - INFO - Leaching::run():time[d]=7.3
# [24431] 2023-12-23 03:35:14,641 - cortix - INFO - Leaching::run():time[d]=7.4
# [24431] 2023-12-23 03:35:14,735 - cortix - INFO - Leaching::run():time[d]=7.4
# [24431] 2023-12-23 03:35:14,827 - cortix - INFO - Leaching::run():time[d]=7.5
# [24431] 2023-12-23 03:35:14,925 - cortix - INFO - Leaching::run():time[d]=7.5
# [24431] 2023-12-23 03:35:15,015 - cortix - INFO - Leaching::run():time[d]=7.5
# [24431] 2023-12-23 03:35:15,107 - cortix - INFO - Leaching::run():time[d]=7.6
# [24431] 2023-12-23 03:35:15,207 - cortix - INFO - Leaching::run():time[d]=7.6
# [24431] 2023-12-23 03:35:15,306 - cortix - INFO - Leaching::run():time[d]=7.7
# [24431] 2023-12-23 03:35:15,396 - cortix - INFO - Leaching::run():time[d]=7.7
# [24431] 2023-12-23 03:35:15,497 - cortix - INFO - Leaching::run():time[d]=7.8
# [24431] 2023-12-23 03:35:15,598 - cortix - INFO - Leaching::run():time[d]=7.8
# [24431] 2023-12-23 03:35:15,692 - cortix - INFO - Leaching::run():time[d]=7.8
# [24431] 2023-12-23 03:35:15,790 - cortix - INFO - Leaching::run():time[d]=7.9
# [24431] 2023-12-23 03:35:15,882 - cortix - INFO - Leaching::run():time[d]=7.9
# [24431] 2023-12-23 03:35:15,972 - cortix - INFO - Leaching::run():time[d]=8.0
# [24431] 2023-12-23 03:35:16,056 - cortix - INFO - Leaching::run():time[d]=8.0
# [24431] 2023-12-23 03:35:16,150 - cortix - INFO - Leaching::run():time[d]=8.0
# [24431] 2023-12-23 03:35:16,239 - cortix - INFO - Leaching::run():time[d]=8.1
# [24431] 2023-12-23 03:35:16,334 - cortix - INFO - Leaching::run():time[d]=8.1
# [24431] 2023-12-23 03:35:16,433 - cortix - INFO - Leaching::run():time[d]=8.2
# [24431] 2023-12-23 03:35:16,522 - cortix - INFO - Leaching::run():time[d]=8.2
# [24431] 2023-12-23 03:35:16,614 - cortix - INFO - Leaching::run():time[d]=8.2
# [24431] 2023-12-23 03:35:16,711 - cortix - INFO - Leaching::run():time[d]=8.3
# [24431] 2023-12-23 03:35:16,800 - cortix - INFO - Leaching::run():time[d]=8.3
# [24431] 2023-12-23 03:35:16,894 - cortix - INFO - Leaching::run():time[d]=8.4
# [24431] 2023-12-23 03:35:16,994 - cortix - INFO - Leaching::run():time[d]=8.4
# [24431] 2023-12-23 03:35:17,084 - cortix - INFO - Leaching::run():time[d]=8.5
# [24431] 2023-12-23 03:35:17,177 - cortix - INFO - Leaching::run():time[d]=8.5
# [24431] 2023-12-23 03:35:17,277 - cortix - INFO - Leaching::run():time[d]=8.5
# [24431] 2023-12-23 03:35:17,366 - cortix - INFO - Leaching::run():time[d]=8.6
# [24431] 2023-12-23 03:35:17,459 - cortix - INFO - Leaching::run():time[d]=8.6
# [24431] 2023-12-23 03:35:17,546 - cortix - INFO - Leaching::run():time[d]=8.7
# [24431] 2023-12-23 03:35:17,642 - cortix - INFO - Leaching::run():time[d]=8.7
# [24431] 2023-12-23 03:35:17,730 - cortix - INFO - Leaching::run():time[d]=8.8
# [24431] 2023-12-23 03:35:17,828 - cortix - INFO - Leaching::run():time[d]=8.8
# [24431] 2023-12-23 03:35:17,915 - cortix - INFO - Leaching::run():time[d]=8.8
# [24431] 2023-12-23 03:35:18,000 - cortix - INFO - Leaching::run():time[d]=8.9
# [24431] 2023-12-23 03:35:18,087 - cortix - INFO - Leaching::run():time[d]=8.9
# [24431] 2023-12-23 03:35:18,180 - cortix - INFO - Leaching::run():time[d]=9.0
# [24431] 2023-12-23 03:35:18,270 - cortix - INFO - Leaching::run():time[d]=9.0
# [24431] 2023-12-23 03:35:18,359 - cortix - INFO - Leaching::run():time[d]=9.0
# [24431] 2023-12-23 03:35:18,460 - cortix - INFO - Leaching::run():time[d]=9.1
# [24431] 2023-12-23 03:35:18,551 - cortix - INFO - Leaching::run():time[d]=9.1
# [24431] 2023-12-23 03:35:18,645 - cortix - INFO - Leaching::run():time[d]=9.2
# [24431] 2023-12-23 03:35:18,742 - cortix - INFO - Leaching::run():time[d]=9.2
# [24431] 2023-12-23 03:35:18,830 - cortix - INFO - Leaching::run():time[d]=9.2
# [24431] 2023-12-23 03:35:18,919 - cortix - INFO - Leaching::run():time[d]=9.3
# [24431] 2023-12-23 03:35:19,017 - cortix - INFO - Leaching::run():time[d]=9.3
# [24431] 2023-12-23 03:35:19,111 - cortix - INFO - Leaching::run():time[d]=9.4
# [24431] 2023-12-23 03:35:19,201 - cortix - INFO - Leaching::run():time[d]=9.4
# [24431] 2023-12-23 03:35:19,293 - cortix - INFO - Leaching::run():time[d]=9.5
# [24431] 2023-12-23 03:35:19,382 - cortix - INFO - Leaching::run():time[d]=9.5
# [24431] 2023-12-23 03:35:19,472 - cortix - INFO - Leaching::run():time[d]=9.5
# [24431] 2023-12-23 03:35:19,569 - cortix - INFO - Leaching::run():time[d]=9.6
# [24431] 2023-12-23 03:35:19,661 - cortix - INFO - Leaching::run():time[d]=9.6
# [24431] 2023-12-23 03:35:19,750 - cortix - INFO - Leaching::run():time[d]=9.7
# [24431] 2023-12-23 03:35:19,849 - cortix - INFO - Leaching::run():time[d]=9.7
# [24431] 2023-12-23 03:35:19,944 - cortix - INFO - Leaching::run():time[d]=9.8
# [24431] 2023-12-23 03:35:20,036 - cortix - INFO - Leaching::run():time[d]=9.8
# [24431] 2023-12-23 03:35:20,133 - cortix - INFO - Leaching::run():time[d]=9.8
# [24431] 2023-12-23 03:35:20,229 - cortix - INFO - Leaching::run():time[d]=9.9
# [24431] 2023-12-23 03:35:20,321 - cortix - INFO - Leaching::run():time[d]=9.9
# [24431] 2023-12-23 03:35:20,420 - cortix - INFO - Leaching::run():time[d]=10.0
# [24431] 2023-12-23 03:35:20,514 - cortix - INFO - Leaching::run():time[d]=10.0
# [24431] 2023-12-23 03:35:20,541 - cortix - INFO - run()::Elapsed wall clock time [s]: 22.04
# [24431] 2023-12-23 03:35:20,542 - cortix - INFO - Closed Cortix object.
# _____________________________________________________________________________
#                            T E R M I N A T I N G
# _____________________________________________________________________________
#       ...                                        s       .     (TAAG Fraktur)
#    xH88"`~ .x8X                                 :8      @88>
#  :8888   .f"8888Hf        u.      .u    .      .88      %8P      uL   ..
# :8888>  X8L  ^""`   ...ue888b   .d88B :@8c    :888ooo    .     .@88b  @88R
# X8888  X888h        888R Y888r ="8888f8888r -*8888888  .@88u  ""Y888k/"*P
# 88888  !88888.      888R I888>   4888>"88"    8888    888E`    Y888L
# 88888   %88888      888R I888>   4888> "      8888      888E      8888
# 88888 `> `8888>     888R I888>   4888>        8888      888E      `888N
# `8888L %  ?888   ! u8888cJ888   .d888L .+    .8888Lu=   888E   .u./"888&
#  `8888  `-*""   /   "*888*P"    ^"8888*"     ^%888*     888&  d888" Y888*"
#    "888.      :"      "Y"          "Y"         "Y"      R888" ` "Y   Y"
#      `""***~"`                                           ""
#                              https://cortix.org
# _____________________________________________________________________________
# [24431] 2023-12-23 03:35:20,543 - cortix - INFO - close()::Elapsed wall clock time [s]: 22.04

# %%
'''Recover modules data'''
leaching = wm_net.modules[0]

# %%
'''Leaching data'''
leaching.preleach_phase.plot(['liquid-volume','mass-flowrate','mass-density'],show=True,figsize=[14,8])
leaching.acidleach_phase.plot(['liquid-volume','mass-flowrate','mass-density'],show=True,figsize=[14,8])

# %% [markdown]
# ## [References](#toc)<a id="refs"></a>
