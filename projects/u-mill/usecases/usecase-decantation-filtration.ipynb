# %% [markdown]
# **Engy-4390** Nuclear Systems Design and Analysis, UMass Lowell, Chem. Eng. Nuclear Program Fall 2023
#
# # Uranium Mill Network Dynamics Simulation
# $
#   \newcommand{\Amtrx}{\boldsymbol{\mathsf{A}}}
#   \newcommand{\Bmtrx}{\boldsymbol{\mathsf{B}}}
#   \newcommand{\Mmtrx}{\boldsymbol{\mathsf{M}}}
#   \newcommand{\Imtrx}{\boldsymbol{\mathsf{I}}}
#   \newcommand{\Pmtrx}{\boldsymbol{\mathsf{P}}}
#   \newcommand{\Lmtrx}{\boldsymbol{\mathsf{L}}}
#   \newcommand{\Umtrx}{\boldsymbol{\mathsf{U}}}
#   \newcommand{\Smtrx}{\boldsymbol{\mathsf{S}}}
#   \newcommand{\xvec}{\boldsymbol{\mathsf{x}}}
#   \newcommand{\uvar}{\boldsymbol{u}}
#   \newcommand{\fvar}{\boldsymbol{f}}
#   \newcommand{\avec}{\boldsymbol{\mathsf{a}}}
#   \newcommand{\bvec}{\boldsymbol{\mathsf{b}}}
#   \newcommand{\cvec}{\boldsymbol{\mathsf{c}}}
#   \newcommand{\rvec}{\boldsymbol{\mathsf{r}}}
#   \newcommand{\mvec}{\boldsymbol{\mathsf{m}}}
#   \newcommand{\gvec}{\boldsymbol{\mathsf{g}}}
#   \newcommand{\zerovec}{\boldsymbol{\mathsf{0}}}
#   \newcommand{\norm}[1]{\bigl\lVert{#1}\bigr\rVert}
#   \newcommand{\transpose}[1]{{#1}^\top}
#   \DeclareMathOperator{\rank}{rank}
#   \newcommand{\Power}{\mathcal{P}}
# $

# %% [markdown]
# ## Stand-Alone Decantation-Filtration Module
# In construction...<br>
# [Project Repository on `GitHub`](https://github.com/dpploy/engy-4390/tree/main/projects/u-mill)

# %% [markdown]
# ---
# ## Table of Contents<a id="toc"></a>
# * [Objectives](#obj)
# * [References](#refs)
# ---

# %% [markdown]
# ## [Objectives](#toc)<a id="obj"></a>

# %% [markdown]
# - Test the implementation of coupled modules in Cortix.
# - Present an executable environment for learning how to use the Cortix modules developed for a simplified Whit Mesa Milling flowsheet.

# %%
'''Setup a White Mesa plant'''
from cortix import Cortix
from cortix import Network
import unit
white_mesa = Cortix(use_mpi=False, splash=True) # System top level
wm_net = white_mesa.network = Network() # Network
# Out:
# [12392] 2023-12-23 20:46:55,655 - cortix - INFO - Created Cortix object
# _____________________________________________________________________________
#                              L A U N C H I N G
# _____________________________________________________________________________
#       ...                                        s       .     (TAAG Fraktur)
#    xH88"`~ .x8X                                 :8      @88>
#  :8888   .f"8888Hf        u.      .u    .      .88      %8P      uL   ..
# :8888>  X8L  ^""`   ...ue888b   .d88B :@8c    :888ooo    .     .@88b  @88R
# X8888  X888h        888R Y888r ="8888f8888r -*8888888  .@88u  ""Y888k/"*P
# 88888  !88888.      888R I888>   4888>"88"    8888    888E`    Y888L
# 88888   %88888      888R I888>   4888> "      8888      888E      8888
# 88888 `> `8888>     888R I888>   4888>        8888      888E      `888N
# `8888L %  ?888   ! u8888cJ888   .d888L .+    .8888Lu=   888E   .u./"888&
#  `8888  `-*""   /   "*888*P"    ^"8888*"     ^%888*     888&  d888" Y888*"
#    "888.      :"      "Y"          "Y"         "Y"      R888" ` "Y   Y"
#      `""***~"`                                           ""
#                              https://cortix.org
# _____________________________________________________________________________

# %%
'''Setup Decantation-Filtration'''
import src.decantation_filtration # this will give access to the python module docstring
decant_filt = src.decantation_filtration.DecantationFiltration()
wm_net.module(decant_filt) 
wm_net.draw(engine='circo', node_shape='folder', ports=True)

# %% [markdown]
# Documentation options:
#  + Live notebook run on *code* cell: `help(src.decantation_filtration)`
#  + On the web: [source](https://github.com/dpploy/engy-4390/blob/main/projects/u-mill/white_mesa/decantation_filtration.py)

# %%
'''Initialize run'''
end_time = 10*unit.day
time_step = 10.0*unit.minute
show_time = (True, unit.hour)

decant_filt.end_time = end_time
decant_filt.time_step = time_step
decant_filt.show_time = show_time

# %%
'''Run White Mesa and shutdown'''   
white_mesa.run()
white_mesa.close()
# Out:
# [12392] 2023-12-23 20:46:56,101 - cortix - INFO - Launching Module <src.decantation_filtration.DecantationFiltration object at 0x7f47bc05ac10>
# [12392] 2023-12-23 20:46:56,109 - cortix - INFO - Decantation-Filtration::run():time[d]=0.0
# [12392] 2023-12-23 20:46:56,368 - cortix - INFO - Decantation-Filtration::run():time[d]=0.0
# [12392] 2023-12-23 20:46:56,647 - cortix - INFO - Decantation-Filtration::run():time[d]=0.1
# [12392] 2023-12-23 20:46:56,873 - cortix - INFO - Decantation-Filtration::run():time[d]=0.1
# [12392] 2023-12-23 20:46:57,140 - cortix - INFO - Decantation-Filtration::run():time[d]=0.2
# [12392] 2023-12-23 20:46:57,435 - cortix - INFO - Decantation-Filtration::run():time[d]=0.2
# [12392] 2023-12-23 20:46:57,725 - cortix - INFO - Decantation-Filtration::run():time[d]=0.2
# [12392] 2023-12-23 20:46:57,961 - cortix - INFO - Decantation-Filtration::run():time[d]=0.3
# [12392] 2023-12-23 20:46:58,190 - cortix - INFO - Decantation-Filtration::run():time[d]=0.3
# [12392] 2023-12-23 20:46:58,486 - cortix - INFO - Decantation-Filtration::run():time[d]=0.4
# [12392] 2023-12-23 20:46:58,756 - cortix - INFO - Decantation-Filtration::run():time[d]=0.4
# [12392] 2023-12-23 20:46:59,016 - cortix - INFO - Decantation-Filtration::run():time[d]=0.5
# [12392] 2023-12-23 20:46:59,286 - cortix - INFO - Decantation-Filtration::run():time[d]=0.5
# [12392] 2023-12-23 20:46:59,574 - cortix - INFO - Decantation-Filtration::run():time[d]=0.5
# [12392] 2023-12-23 20:46:59,851 - cortix - INFO - Decantation-Filtration::run():time[d]=0.6
# [12392] 2023-12-23 20:47:00,128 - cortix - INFO - Decantation-Filtration::run():time[d]=0.6
# [12392] 2023-12-23 20:47:00,427 - cortix - INFO - Decantation-Filtration::run():time[d]=0.7
# [12392] 2023-12-23 20:47:00,674 - cortix - INFO - Decantation-Filtration::run():time[d]=0.7
# [12392] 2023-12-23 20:47:00,911 - cortix - INFO - Decantation-Filtration::run():time[d]=0.8
# [12392] 2023-12-23 20:47:01,178 - cortix - INFO - Decantation-Filtration::run():time[d]=0.8
# [12392] 2023-12-23 20:47:01,463 - cortix - INFO - Decantation-Filtration::run():time[d]=0.8
# [12392] 2023-12-23 20:47:01,703 - cortix - INFO - Decantation-Filtration::run():time[d]=0.9
# [12392] 2023-12-23 20:47:01,941 - cortix - INFO - Decantation-Filtration::run():time[d]=0.9
# [12392] 2023-12-23 20:47:02,180 - cortix - INFO - Decantation-Filtration::run():time[d]=1.0
# [12392] 2023-12-23 20:47:02,438 - cortix - INFO - Decantation-Filtration::run():time[d]=1.0
# [12392] 2023-12-23 20:47:02,676 - cortix - INFO - Decantation-Filtration::run():time[d]=1.0
# [12392] 2023-12-23 20:47:02,914 - cortix - INFO - Decantation-Filtration::run():time[d]=1.1
# [12392] 2023-12-23 20:47:03,156 - cortix - INFO - Decantation-Filtration::run():time[d]=1.1
# [12392] 2023-12-23 20:47:03,408 - cortix - INFO - Decantation-Filtration::run():time[d]=1.2
# [12392] 2023-12-23 20:47:03,641 - cortix - INFO - Decantation-Filtration::run():time[d]=1.2
# [12392] 2023-12-23 20:47:03,873 - cortix - INFO - Decantation-Filtration::run():time[d]=1.2
# [12392] 2023-12-23 20:47:04,109 - cortix - INFO - Decantation-Filtration::run():time[d]=1.3
# [12392] 2023-12-23 20:47:04,351 - cortix - INFO - Decantation-Filtration::run():time[d]=1.3
# [12392] 2023-12-23 20:47:04,594 - cortix - INFO - Decantation-Filtration::run():time[d]=1.4
# [12392] 2023-12-23 20:47:04,947 - cortix - INFO - Decantation-Filtration::run():time[d]=1.4
# [12392] 2023-12-23 20:47:05,260 - cortix - INFO - Decantation-Filtration::run():time[d]=1.5
# [12392] 2023-12-23 20:47:05,630 - cortix - INFO - Decantation-Filtration::run():time[d]=1.5
# [12392] 2023-12-23 20:47:05,950 - cortix - INFO - Decantation-Filtration::run():time[d]=1.5
# [12392] 2023-12-23 20:47:06,241 - cortix - INFO - Decantation-Filtration::run():time[d]=1.6
# [12392] 2023-12-23 20:47:06,553 - cortix - INFO - Decantation-Filtration::run():time[d]=1.6
# [12392] 2023-12-23 20:47:06,847 - cortix - INFO - Decantation-Filtration::run():time[d]=1.7
# [12392] 2023-12-23 20:47:07,181 - cortix - INFO - Decantation-Filtration::run():time[d]=1.7
# [12392] 2023-12-23 20:47:07,548 - cortix - INFO - Decantation-Filtration::run():time[d]=1.8
# [12392] 2023-12-23 20:47:07,861 - cortix - INFO - Decantation-Filtration::run():time[d]=1.8
# [12392] 2023-12-23 20:47:08,235 - cortix - INFO - Decantation-Filtration::run():time[d]=1.8
# [12392] 2023-12-23 20:47:08,606 - cortix - INFO - Decantation-Filtration::run():time[d]=1.9
# [12392] 2023-12-23 20:47:08,946 - cortix - INFO - Decantation-Filtration::run():time[d]=1.9
# [12392] 2023-12-23 20:47:09,273 - cortix - INFO - Decantation-Filtration::run():time[d]=2.0
# [12392] 2023-12-23 20:47:09,574 - cortix - INFO - Decantation-Filtration::run():time[d]=2.0
# [12392] 2023-12-23 20:47:09,874 - cortix - INFO - Decantation-Filtration::run():time[d]=2.0
# [12392] 2023-12-23 20:47:10,195 - cortix - INFO - Decantation-Filtration::run():time[d]=2.1
# [12392] 2023-12-23 20:47:10,497 - cortix - INFO - Decantation-Filtration::run():time[d]=2.1
# [12392] 2023-12-23 20:47:10,814 - cortix - INFO - Decantation-Filtration::run():time[d]=2.2
# [12392] 2023-12-23 20:47:11,098 - cortix - INFO - Decantation-Filtration::run():time[d]=2.2
# [12392] 2023-12-23 20:47:11,419 - cortix - INFO - Decantation-Filtration::run():time[d]=2.2
# [12392] 2023-12-23 20:47:11,699 - cortix - INFO - Decantation-Filtration::run():time[d]=2.3
# [12392] 2023-12-23 20:47:11,977 - cortix - INFO - Decantation-Filtration::run():time[d]=2.3
# [12392] 2023-12-23 20:47:12,277 - cortix - INFO - Decantation-Filtration::run():time[d]=2.4
# [12392] 2023-12-23 20:47:12,546 - cortix - INFO - Decantation-Filtration::run():time[d]=2.4
# [12392] 2023-12-23 20:47:12,826 - cortix - INFO - Decantation-Filtration::run():time[d]=2.5
# [12392] 2023-12-23 20:47:13,110 - cortix - INFO - Decantation-Filtration::run():time[d]=2.5
# [12392] 2023-12-23 20:47:13,380 - cortix - INFO - Decantation-Filtration::run():time[d]=2.5
# [12392] 2023-12-23 20:47:13,649 - cortix - INFO - Decantation-Filtration::run():time[d]=2.6
# [12392] 2023-12-23 20:47:13,904 - cortix - INFO - Decantation-Filtration::run():time[d]=2.6
# [12392] 2023-12-23 20:47:14,180 - cortix - INFO - Decantation-Filtration::run():time[d]=2.7
# [12392] 2023-12-23 20:47:14,469 - cortix - INFO - Decantation-Filtration::run():time[d]=2.7
# [12392] 2023-12-23 20:47:14,775 - cortix - INFO - Decantation-Filtration::run():time[d]=2.8
# [12392] 2023-12-23 20:47:15,094 - cortix - INFO - Decantation-Filtration::run():time[d]=2.8
# [12392] 2023-12-23 20:47:15,359 - cortix - INFO - Decantation-Filtration::run():time[d]=2.8
# [12392] 2023-12-23 20:47:15,627 - cortix - INFO - Decantation-Filtration::run():time[d]=2.9
# [12392] 2023-12-23 20:47:15,894 - cortix - INFO - Decantation-Filtration::run():time[d]=2.9
# [12392] 2023-12-23 20:47:16,294 - cortix - INFO - Decantation-Filtration::run():time[d]=3.0
# [12392] 2023-12-23 20:47:16,923 - cortix - INFO - Decantation-Filtration::run():time[d]=3.0
# [12392] 2023-12-23 20:47:17,267 - cortix - INFO - Decantation-Filtration::run():time[d]=3.0
# [12392] 2023-12-23 20:47:17,530 - cortix - INFO - Decantation-Filtration::run():time[d]=3.1
# [12392] 2023-12-23 20:47:17,800 - cortix - INFO - Decantation-Filtration::run():time[d]=3.1
# [12392] 2023-12-23 20:47:18,166 - cortix - INFO - Decantation-Filtration::run():time[d]=3.2
# [12392] 2023-12-23 20:47:18,943 - cortix - INFO - Decantation-Filtration::run():time[d]=3.2
# [12392] 2023-12-23 20:47:19,312 - cortix - INFO - Decantation-Filtration::run():time[d]=3.2
# [12392] 2023-12-23 20:47:19,591 - cortix - INFO - Decantation-Filtration::run():time[d]=3.3
# [12392] 2023-12-23 20:47:19,855 - cortix - INFO - Decantation-Filtration::run():time[d]=3.3
# [12392] 2023-12-23 20:47:20,305 - cortix - INFO - Decantation-Filtration::run():time[d]=3.4
# [12392] 2023-12-23 20:47:21,051 - cortix - INFO - Decantation-Filtration::run():time[d]=3.4
# [12392] 2023-12-23 20:47:21,331 - cortix - INFO - Decantation-Filtration::run():time[d]=3.5
# [12392] 2023-12-23 20:47:21,589 - cortix - INFO - Decantation-Filtration::run():time[d]=3.5
# [12392] 2023-12-23 20:47:21,838 - cortix - INFO - Decantation-Filtration::run():time[d]=3.5
# [12392] 2023-12-23 20:47:22,319 - cortix - INFO - Decantation-Filtration::run():time[d]=3.6
# [12392] 2023-12-23 20:47:22,928 - cortix - INFO - Decantation-Filtration::run():time[d]=3.6
# [12392] 2023-12-23 20:47:23,254 - cortix - INFO - Decantation-Filtration::run():time[d]=3.7
# [12392] 2023-12-23 20:47:23,652 - cortix - INFO - Decantation-Filtration::run():time[d]=3.7
# [12392] 2023-12-23 20:47:24,306 - cortix - INFO - Decantation-Filtration::run():time[d]=3.8
# [12392] 2023-12-23 20:47:24,944 - cortix - INFO - Decantation-Filtration::run():time[d]=3.8
# [12392] 2023-12-23 20:47:25,322 - cortix - INFO - Decantation-Filtration::run():time[d]=3.8
# [12392] 2023-12-23 20:47:25,617 - cortix - INFO - Decantation-Filtration::run():time[d]=3.9
# [12392] 2023-12-23 20:47:26,028 - cortix - INFO - Decantation-Filtration::run():time[d]=3.9
# [12392] 2023-12-23 20:47:26,569 - cortix - INFO - Decantation-Filtration::run():time[d]=4.0
# [12392] 2023-12-23 20:47:27,024 - cortix - INFO - Decantation-Filtration::run():time[d]=4.0
# [12392] 2023-12-23 20:47:27,389 - cortix - INFO - Decantation-Filtration::run():time[d]=4.0
# [12392] 2023-12-23 20:47:27,770 - cortix - INFO - Decantation-Filtration::run():time[d]=4.1
# [12392] 2023-12-23 20:47:28,470 - cortix - INFO - Decantation-Filtration::run():time[d]=4.1
# [12392] 2023-12-23 20:47:29,031 - cortix - INFO - Decantation-Filtration::run():time[d]=4.2
# [12392] 2023-12-23 20:47:29,356 - cortix - INFO - Decantation-Filtration::run():time[d]=4.2
# [12392] 2023-12-23 20:47:29,684 - cortix - INFO - Decantation-Filtration::run():time[d]=4.2
# [12392] 2023-12-23 20:47:30,289 - cortix - INFO - Decantation-Filtration::run():time[d]=4.3
# [12392] 2023-12-23 20:47:30,804 - cortix - INFO - Decantation-Filtration::run():time[d]=4.3
# [12392] 2023-12-23 20:47:31,158 - cortix - INFO - Decantation-Filtration::run():time[d]=4.4
# [12392] 2023-12-23 20:47:31,465 - cortix - INFO - Decantation-Filtration::run():time[d]=4.4
# [12392] 2023-12-23 20:47:31,994 - cortix - INFO - Decantation-Filtration::run():time[d]=4.5
# [12392] 2023-12-23 20:47:32,554 - cortix - INFO - Decantation-Filtration::run():time[d]=4.5
# [12392] 2023-12-23 20:47:32,926 - cortix - INFO - Decantation-Filtration::run():time[d]=4.5
# [12392] 2023-12-23 20:47:33,277 - cortix - INFO - Decantation-Filtration::run():time[d]=4.6
# [12392] 2023-12-23 20:47:33,904 - cortix - INFO - Decantation-Filtration::run():time[d]=4.6
# [12392] 2023-12-23 20:47:34,641 - cortix - INFO - Decantation-Filtration::run():time[d]=4.7
# [12392] 2023-12-23 20:47:35,031 - cortix - INFO - Decantation-Filtration::run():time[d]=4.7
# [12392] 2023-12-23 20:47:35,322 - cortix - INFO - Decantation-Filtration::run():time[d]=4.8
# [12392] 2023-12-23 20:47:35,675 - cortix - INFO - Decantation-Filtration::run():time[d]=4.8
# [12392] 2023-12-23 20:47:36,465 - cortix - INFO - Decantation-Filtration::run():time[d]=4.8
# [12392] 2023-12-23 20:47:36,917 - cortix - INFO - Decantation-Filtration::run():time[d]=4.9
# [12392] 2023-12-23 20:47:37,196 - cortix - INFO - Decantation-Filtration::run():time[d]=4.9
# [12392] 2023-12-23 20:47:37,468 - cortix - INFO - Decantation-Filtration::run():time[d]=5.0
# [12392] 2023-12-23 20:47:38,011 - cortix - INFO - Decantation-Filtration::run():time[d]=5.0
# [12392] 2023-12-23 20:47:38,622 - cortix - INFO - Decantation-Filtration::run():time[d]=5.0
# [12392] 2023-12-23 20:47:38,917 - cortix - INFO - Decantation-Filtration::run():time[d]=5.1
# [12392] 2023-12-23 20:47:39,184 - cortix - INFO - Decantation-Filtration::run():time[d]=5.1
# [12392] 2023-12-23 20:47:39,623 - cortix - INFO - Decantation-Filtration::run():time[d]=5.2
# [12392] 2023-12-23 20:47:40,238 - cortix - INFO - Decantation-Filtration::run():time[d]=5.2
# [12392] 2023-12-23 20:47:40,790 - cortix - INFO - Decantation-Filtration::run():time[d]=5.2
# [12392] 2023-12-23 20:47:41,062 - cortix - INFO - Decantation-Filtration::run():time[d]=5.3
# [12392] 2023-12-23 20:47:41,353 - cortix - INFO - Decantation-Filtration::run():time[d]=5.3
# [12392] 2023-12-23 20:47:42,078 - cortix - INFO - Decantation-Filtration::run():time[d]=5.4
# [12392] 2023-12-23 20:47:42,563 - cortix - INFO - Decantation-Filtration::run():time[d]=5.4
# [12392] 2023-12-23 20:47:42,832 - cortix - INFO - Decantation-Filtration::run():time[d]=5.5
# [12392] 2023-12-23 20:47:43,078 - cortix - INFO - Decantation-Filtration::run():time[d]=5.5
# [12392] 2023-12-23 20:47:43,394 - cortix - INFO - Decantation-Filtration::run():time[d]=5.5
# [12392] 2023-12-23 20:47:43,934 - cortix - INFO - Decantation-Filtration::run():time[d]=5.6
# [12392] 2023-12-23 20:47:44,445 - cortix - INFO - Decantation-Filtration::run():time[d]=5.6
# [12392] 2023-12-23 20:47:44,775 - cortix - INFO - Decantation-Filtration::run():time[d]=5.7
# [12392] 2023-12-23 20:47:45,088 - cortix - INFO - Decantation-Filtration::run():time[d]=5.7
# [12392] 2023-12-23 20:47:45,441 - cortix - INFO - Decantation-Filtration::run():time[d]=5.8
# [12392] 2023-12-23 20:47:46,046 - cortix - INFO - Decantation-Filtration::run():time[d]=5.8
# [12392] 2023-12-23 20:47:46,509 - cortix - INFO - Decantation-Filtration::run():time[d]=5.8
# [12392] 2023-12-23 20:47:46,786 - cortix - INFO - Decantation-Filtration::run():time[d]=5.9
# [12392] 2023-12-23 20:47:47,041 - cortix - INFO - Decantation-Filtration::run():time[d]=5.9
# [12392] 2023-12-23 20:47:47,360 - cortix - INFO - Decantation-Filtration::run():time[d]=6.0
# [12392] 2023-12-23 20:47:47,875 - cortix - INFO - Decantation-Filtration::run():time[d]=6.0
# [12392] 2023-12-23 20:47:48,371 - cortix - INFO - Decantation-Filtration::run():time[d]=6.0
# [12392] 2023-12-23 20:47:48,624 - cortix - INFO - Decantation-Filtration::run():time[d]=6.1
# [12392] 2023-12-23 20:47:48,900 - cortix - INFO - Decantation-Filtration::run():time[d]=6.1
# [12392] 2023-12-23 20:47:49,207 - cortix - INFO - Decantation-Filtration::run():time[d]=6.2
# [12392] 2023-12-23 20:47:49,768 - cortix - INFO - Decantation-Filtration::run():time[d]=6.2
# [12392] 2023-12-23 20:47:50,279 - cortix - INFO - Decantation-Filtration::run():time[d]=6.2
# [12392] 2023-12-23 20:47:50,535 - cortix - INFO - Decantation-Filtration::run():time[d]=6.3
# [12392] 2023-12-23 20:47:50,795 - cortix - INFO - Decantation-Filtration::run():time[d]=6.3
# [12392] 2023-12-23 20:47:51,065 - cortix - INFO - Decantation-Filtration::run():time[d]=6.4
# [12392] 2023-12-23 20:47:51,555 - cortix - INFO - Decantation-Filtration::run():time[d]=6.4
# [12392] 2023-12-23 20:47:52,077 - cortix - INFO - Decantation-Filtration::run():time[d]=6.5
# [12392] 2023-12-23 20:47:52,471 - cortix - INFO - Decantation-Filtration::run():time[d]=6.5
# [12392] 2023-12-23 20:47:52,807 - cortix - INFO - Decantation-Filtration::run():time[d]=6.5
# [12392] 2023-12-23 20:47:53,304 - cortix - INFO - Decantation-Filtration::run():time[d]=6.6
# [12392] 2023-12-23 20:47:53,987 - cortix - INFO - Decantation-Filtration::run():time[d]=6.6
# [12392] 2023-12-23 20:47:54,386 - cortix - INFO - Decantation-Filtration::run():time[d]=6.7
# [12392] 2023-12-23 20:47:54,705 - cortix - INFO - Decantation-Filtration::run():time[d]=6.7
# [12392] 2023-12-23 20:47:54,981 - cortix - INFO - Decantation-Filtration::run():time[d]=6.8
# [12392] 2023-12-23 20:47:55,434 - cortix - INFO - Decantation-Filtration::run():time[d]=6.8
# [12392] 2023-12-23 20:47:56,139 - cortix - INFO - Decantation-Filtration::run():time[d]=6.8
# [12392] 2023-12-23 20:47:56,457 - cortix - INFO - Decantation-Filtration::run():time[d]=6.9
# [12392] 2023-12-23 20:47:56,770 - cortix - INFO - Decantation-Filtration::run():time[d]=6.9
# [12392] 2023-12-23 20:47:57,150 - cortix - INFO - Decantation-Filtration::run():time[d]=7.0
# [12392] 2023-12-23 20:47:57,754 - cortix - INFO - Decantation-Filtration::run():time[d]=7.0
# [12392] 2023-12-23 20:47:58,190 - cortix - INFO - Decantation-Filtration::run():time[d]=7.0
# [12392] 2023-12-23 20:47:58,452 - cortix - INFO - Decantation-Filtration::run():time[d]=7.1
# [12392] 2023-12-23 20:47:58,708 - cortix - INFO - Decantation-Filtration::run():time[d]=7.1
# [12392] 2023-12-23 20:47:58,956 - cortix - INFO - Decantation-Filtration::run():time[d]=7.2
# [12392] 2023-12-23 20:47:59,472 - cortix - INFO - Decantation-Filtration::run():time[d]=7.2
# [12392] 2023-12-23 20:47:59,953 - cortix - INFO - Decantation-Filtration::run():time[d]=7.2
# [12392] 2023-12-23 20:48:00,456 - cortix - INFO - Decantation-Filtration::run():time[d]=7.3
# [12392] 2023-12-23 20:48:00,736 - cortix - INFO - Decantation-Filtration::run():time[d]=7.3
# [12392] 2023-12-23 20:48:01,079 - cortix - INFO - Decantation-Filtration::run():time[d]=7.4
# [12392] 2023-12-23 20:48:01,702 - cortix - INFO - Decantation-Filtration::run():time[d]=7.4
# [12392] 2023-12-23 20:48:02,166 - cortix - INFO - Decantation-Filtration::run():time[d]=7.5
# [12392] 2023-12-23 20:48:02,570 - cortix - INFO - Decantation-Filtration::run():time[d]=7.5
# [12392] 2023-12-23 20:48:02,978 - cortix - INFO - Decantation-Filtration::run():time[d]=7.5
# [12392] 2023-12-23 20:48:03,683 - cortix - INFO - Decantation-Filtration::run():time[d]=7.6
# [12392] 2023-12-23 20:48:04,208 - cortix - INFO - Decantation-Filtration::run():time[d]=7.6
# [12392] 2023-12-23 20:48:04,589 - cortix - INFO - Decantation-Filtration::run():time[d]=7.7
# [12392] 2023-12-23 20:48:04,982 - cortix - INFO - Decantation-Filtration::run():time[d]=7.7
# [12392] 2023-12-23 20:48:05,511 - cortix - INFO - Decantation-Filtration::run():time[d]=7.8
# [12392] 2023-12-23 20:48:06,000 - cortix - INFO - Decantation-Filtration::run():time[d]=7.8
# [12392] 2023-12-23 20:48:06,270 - cortix - INFO - Decantation-Filtration::run():time[d]=7.8
# [12392] 2023-12-23 20:48:06,541 - cortix - INFO - Decantation-Filtration::run():time[d]=7.9
# [12392] 2023-12-23 20:48:06,839 - cortix - INFO - Decantation-Filtration::run():time[d]=7.9
# [12392] 2023-12-23 20:48:07,421 - cortix - INFO - Decantation-Filtration::run():time[d]=8.0
# [12392] 2023-12-23 20:48:07,975 - cortix - INFO - Decantation-Filtration::run():time[d]=8.0
# [12392] 2023-12-23 20:48:08,238 - cortix - INFO - Decantation-Filtration::run():time[d]=8.0
# [12392] 2023-12-23 20:48:08,548 - cortix - INFO - Decantation-Filtration::run():time[d]=8.1
# [12392] 2023-12-23 20:48:08,884 - cortix - INFO - Decantation-Filtration::run():time[d]=8.1
# [12392] 2023-12-23 20:48:09,396 - cortix - INFO - Decantation-Filtration::run():time[d]=8.2
# [12392] 2023-12-23 20:48:09,915 - cortix - INFO - Decantation-Filtration::run():time[d]=8.2
# [12392] 2023-12-23 20:48:10,178 - cortix - INFO - Decantation-Filtration::run():time[d]=8.2
# [12392] 2023-12-23 20:48:10,444 - cortix - INFO - Decantation-Filtration::run():time[d]=8.3
# [12392] 2023-12-23 20:48:10,699 - cortix - INFO - Decantation-Filtration::run():time[d]=8.3
# [12392] 2023-12-23 20:48:11,232 - cortix - INFO - Decantation-Filtration::run():time[d]=8.4
# [12392] 2023-12-23 20:48:11,790 - cortix - INFO - Decantation-Filtration::run():time[d]=8.4
# [12392] 2023-12-23 20:48:12,046 - cortix - INFO - Decantation-Filtration::run():time[d]=8.5
# [12392] 2023-12-23 20:48:12,295 - cortix - INFO - Decantation-Filtration::run():time[d]=8.5
# [12392] 2023-12-23 20:48:12,576 - cortix - INFO - Decantation-Filtration::run():time[d]=8.5
# [12392] 2023-12-23 20:48:13,093 - cortix - INFO - Decantation-Filtration::run():time[d]=8.6
# [12392] 2023-12-23 20:48:13,613 - cortix - INFO - Decantation-Filtration::run():time[d]=8.6
# [12392] 2023-12-23 20:48:13,930 - cortix - INFO - Decantation-Filtration::run():time[d]=8.7
# [12392] 2023-12-23 20:48:14,199 - cortix - INFO - Decantation-Filtration::run():time[d]=8.7
# [12392] 2023-12-23 20:48:14,472 - cortix - INFO - Decantation-Filtration::run():time[d]=8.8
# [12392] 2023-12-23 20:48:14,873 - cortix - INFO - Decantation-Filtration::run():time[d]=8.8
# [12392] 2023-12-23 20:48:15,420 - cortix - INFO - Decantation-Filtration::run():time[d]=8.8
# [12392] 2023-12-23 20:48:15,853 - cortix - INFO - Decantation-Filtration::run():time[d]=8.9
# [12392] 2023-12-23 20:48:16,122 - cortix - INFO - Decantation-Filtration::run():time[d]=8.9
# [12392] 2023-12-23 20:48:16,426 - cortix - INFO - Decantation-Filtration::run():time[d]=9.0
# [12392] 2023-12-23 20:48:16,853 - cortix - INFO - Decantation-Filtration::run():time[d]=9.0
# [12392] 2023-12-23 20:48:17,375 - cortix - INFO - Decantation-Filtration::run():time[d]=9.0
# [12392] 2023-12-23 20:48:17,768 - cortix - INFO - Decantation-Filtration::run():time[d]=9.1
# [12392] 2023-12-23 20:48:18,199 - cortix - INFO - Decantation-Filtration::run():time[d]=9.1
# [12392] 2023-12-23 20:48:18,512 - cortix - INFO - Decantation-Filtration::run():time[d]=9.2
# [12392] 2023-12-23 20:48:19,050 - cortix - INFO - Decantation-Filtration::run():time[d]=9.2
# [12392] 2023-12-23 20:48:19,581 - cortix - INFO - Decantation-Filtration::run():time[d]=9.2
# [12392] 2023-12-23 20:48:19,849 - cortix - INFO - Decantation-Filtration::run():time[d]=9.3
# [12392] 2023-12-23 20:48:20,126 - cortix - INFO - Decantation-Filtration::run():time[d]=9.3
# [12392] 2023-12-23 20:48:20,390 - cortix - INFO - Decantation-Filtration::run():time[d]=9.4
# [12392] 2023-12-23 20:48:20,901 - cortix - INFO - Decantation-Filtration::run():time[d]=9.4
# [12392] 2023-12-23 20:48:21,500 - cortix - INFO - Decantation-Filtration::run():time[d]=9.5
# [12392] 2023-12-23 20:48:21,770 - cortix - INFO - Decantation-Filtration::run():time[d]=9.5
# [12392] 2023-12-23 20:48:22,051 - cortix - INFO - Decantation-Filtration::run():time[d]=9.5
# [12392] 2023-12-23 20:48:22,353 - cortix - INFO - Decantation-Filtration::run():time[d]=9.6
# [12392] 2023-12-23 20:48:22,874 - cortix - INFO - Decantation-Filtration::run():time[d]=9.6
# [12392] 2023-12-23 20:48:23,500 - cortix - INFO - Decantation-Filtration::run():time[d]=9.7
# [12392] 2023-12-23 20:48:23,757 - cortix - INFO - Decantation-Filtration::run():time[d]=9.7
# [12392] 2023-12-23 20:48:24,015 - cortix - INFO - Decantation-Filtration::run():time[d]=9.8
# [12392] 2023-12-23 20:48:24,281 - cortix - INFO - Decantation-Filtration::run():time[d]=9.8
# [12392] 2023-12-23 20:48:24,761 - cortix - INFO - Decantation-Filtration::run():time[d]=9.8
# [12392] 2023-12-23 20:48:25,282 - cortix - INFO - Decantation-Filtration::run():time[d]=9.9
# [12392] 2023-12-23 20:48:25,619 - cortix - INFO - Decantation-Filtration::run():time[d]=9.9
# [12392] 2023-12-23 20:48:25,879 - cortix - INFO - Decantation-Filtration::run():time[d]=10.0
# [12392] 2023-12-23 20:48:26,138 - cortix - INFO - Decantation-Filtration::run():time[d]=10.0
# [12392] 2023-12-23 20:48:26,224 - cortix - INFO - run()::Elapsed wall clock time [s]: 90.57
# [12392] 2023-12-23 20:48:26,227 - cortix - INFO - Closed Cortix object.
# _____________________________________________________________________________
#                            T E R M I N A T I N G
# _____________________________________________________________________________
#       ...                                        s       .     (TAAG Fraktur)
#    xH88"`~ .x8X                                 :8      @88>
#  :8888   .f"8888Hf        u.      .u    .      .88      %8P      uL   ..
# :8888>  X8L  ^""`   ...ue888b   .d88B :@8c    :888ooo    .     .@88b  @88R
# X8888  X888h        888R Y888r ="8888f8888r -*8888888  .@88u  ""Y888k/"*P
# 88888  !88888.      888R I888>   4888>"88"    8888    888E`    Y888L
# 88888   %88888      888R I888>   4888> "      8888      888E      8888
# 88888 `> `8888>     888R I888>   4888>        8888      888E      `888N
# `8888L %  ?888   ! u8888cJ888   .d888L .+    .8888Lu=   888E   .u./"888&
#  `8888  `-*""   /   "*888*P"    ^"8888*"     ^%888*     888&  d888" Y888*"
#    "888.      :"      "Y"          "Y"         "Y"      R888" ` "Y   Y"
#      `""***~"`                                           ""
#                              https://cortix.org
# _____________________________________________________________________________
# [12392] 2023-12-23 20:48:26,229 - cortix - INFO - close()::Elapsed wall clock time [s]: 90.57

# %%
'''Recover modules data'''
decant_filt = wm_net.modules[0]

# %%
'''Decantation/Filtration and plot'''
import matplotlib.pyplot as plt
(quant, time_unit) = decant_filt.std_state_phase.get_quantity_history('liquid-volume')
quant.plot(x_scaling=1/unit.day, x_label='Time [d]',y_label=quant.latex_name+' ['+quant.unit+']')
plt.grid()

# %%
(quant, time_unit) = decant_filt.ccd_state_phase.get_quantity_history('liquid-volume')
quant.plot(x_scaling=1/unit.day, x_label='Time [d]',y_label=quant.latex_name+' ['+quant.unit+']')
plt.grid()

# %%
(quant, time_unit) = decant_filt.ccd_overflow_phase.get_quantity_history('mass-flowrate')
quant.plot(x_scaling=1/unit.day, y_scaling=unit.minute, x_label='Time [d]', y_label=quant.latex_name + ' [kg/min]')
plt.grid()

# %%
(quant, time_unit) = decant_filt.ccd_underflow_phase.get_quantity_history('mass-flowrate')
quant.plot(x_scaling=1/unit.day, y_scaling=unit.minute, x_label='Time [d]', y_label=quant.latex_name + ' [kg/min]')
plt.grid()

# %% [markdown]
# ## [References](#toc)<a id="refs"></a>
