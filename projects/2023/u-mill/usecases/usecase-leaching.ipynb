# %% [markdown]
# **Engy-4390** Nuclear Systems Design and Analysis, UMass Lowell, Chem. Eng. Nuclear Program Fall 2023
#
# # Uranium Mill Network Dynamics Simulation
# $
#   \newcommand{\Amtrx}{\boldsymbol{\mathsf{A}}}
#   \newcommand{\Bmtrx}{\boldsymbol{\mathsf{B}}}
#   \newcommand{\Mmtrx}{\boldsymbol{\mathsf{M}}}
#   \newcommand{\Imtrx}{\boldsymbol{\mathsf{I}}}
#   \newcommand{\Pmtrx}{\boldsymbol{\mathsf{P}}}
#   \newcommand{\Lmtrx}{\boldsymbol{\mathsf{L}}}
#   \newcommand{\Umtrx}{\boldsymbol{\mathsf{U}}}
#   \newcommand{\Smtrx}{\boldsymbol{\mathsf{S}}}
#   \newcommand{\xvec}{\boldsymbol{\mathsf{x}}}
#   \newcommand{\uvar}{\boldsymbol{u}}
#   \newcommand{\fvar}{\boldsymbol{f}}
#   \newcommand{\avec}{\boldsymbol{\mathsf{a}}}
#   \newcommand{\bvec}{\boldsymbol{\mathsf{b}}}
#   \newcommand{\cvec}{\boldsymbol{\mathsf{c}}}
#   \newcommand{\rvec}{\boldsymbol{\mathsf{r}}}
#   \newcommand{\mvec}{\boldsymbol{\mathsf{m}}}
#   \newcommand{\gvec}{\boldsymbol{\mathsf{g}}}
#   \newcommand{\zerovec}{\boldsymbol{\mathsf{0}}}
#   \newcommand{\norm}[1]{\bigl\lVert{#1}\bigr\rVert}
#   \newcommand{\transpose}[1]{{#1}^\top}
#   \DeclareMathOperator{\rank}{rank}
#   \newcommand{\Power}{\mathcal{P}}
# $

# %% [markdown]
# ## Stand-Alone Leaching Module
# In construction...<br>
# [Project Repository on `GitHub`](https://github.com/dpploy/engy-4390/tree/main/projects/u-mill)

# %% [markdown]
# ---
# ## Table of Contents<a id="toc"></a>
# * [Objectives](#obj)
# * [References](#refs)
# ---

# %% [markdown]
# ## [Objectives](#toc)<a id="obj"></a>

# %% [markdown]
# - Test the implementation of coupled modules in Cortix.
# - Present an executable environment for learning how to use the Cortix modules developed for a simplified Whit Mesa Milling flowsheet.

# %%
'''Setup a White Mesa plant'''
from cortix import Cortix
from cortix import Network
from cortix import Units as unit
white_mesa = Cortix(use_mpi=False, splash=True) # System top level
wm_net = white_mesa.network = Network() # Network
# Out:
# [1015] 2023-12-23 23:16:00,902 - cortix - INFO - Created Cortix object
# _____________________________________________________________________________
#                              L A U N C H I N G
# _____________________________________________________________________________
#       ...                                        s       .     (TAAG Fraktur)
#    xH88"`~ .x8X                                 :8      @88>
#  :8888   .f"8888Hf        u.      .u    .      .88      %8P      uL   ..
# :8888>  X8L  ^""`   ...ue888b   .d88B :@8c    :888ooo    .     .@88b  @88R
# X8888  X888h        888R Y888r ="8888f8888r -*8888888  .@88u  ""Y888k/"*P
# 88888  !88888.      888R I888>   4888>"88"    8888    888E`    Y888L
# 88888   %88888      888R I888>   4888> "      8888      888E      8888
# 88888 `> `8888>     888R I888>   4888>        8888      888E      `888N
# `8888L %  ?888   ! u8888cJ888   .d888L .+    .8888Lu=   888E   .u./"888&
#  `8888  `-*""   /   "*888*P"    ^"8888*"     ^%888*     888&  d888" Y888*"
#    "888.      :"      "Y"          "Y"         "Y"      R888" ` "Y   Y"
#      `""***~"`                                           ""
#                              https://cortix.org
# _____________________________________________________________________________

# %%
'''Setup Leaching'''
import src.leaching # this will give access to the python module docstring
leaching = src.leaching.Leaching()
wm_net.module(leaching) 
wm_net.draw(engine='circo', node_shape='folder', ports=True)

# %% [markdown]
# Documentation options:
#  + Live notebook run on *code* cell: `help(src.leaching)`
#  + On the web: [source](https://github.com/dpploy/engy-4390/blob/main/projects/u-mill/white_mesa/leaching.py)

# %%
'''Initialize run'''
end_time = 10*unit.day
time_step = 10.0*unit.minute
show_time = (True, unit.hour)

leaching.end_time = end_time
leaching.time_step = time_step
leaching.show_time = show_time

# %%
'''Run White Mesa and shutdown'''   
white_mesa.run()
white_mesa.close()
# Out:
# [1015] 2023-12-23 23:16:01,643 - cortix - INFO - Launching Module <src.leaching.Leaching object at 0x7f4b6828e4d0>
# [1015] 2023-12-23 23:16:01,659 - cortix - INFO - Leaching::run():time[d]=0.0
# [1015] 2023-12-23 23:16:01,807 - cortix - INFO - Leaching::run():time[d]=0.0
# [1015] 2023-12-23 23:16:01,921 - cortix - INFO - Leaching::run():time[d]=0.1
# [1015] 2023-12-23 23:16:02,031 - cortix - INFO - Leaching::run():time[d]=0.1
# [1015] 2023-12-23 23:16:02,138 - cortix - INFO - Leaching::run():time[d]=0.2
# [1015] 2023-12-23 23:16:02,241 - cortix - INFO - Leaching::run():time[d]=0.2
# [1015] 2023-12-23 23:16:02,344 - cortix - INFO - Leaching::run():time[d]=0.2
# [1015] 2023-12-23 23:16:02,512 - cortix - INFO - Leaching::run():time[d]=0.3
# [1015] 2023-12-23 23:16:02,708 - cortix - INFO - Leaching::run():time[d]=0.3
# [1015] 2023-12-23 23:16:02,904 - cortix - INFO - Leaching::run():time[d]=0.4
# [1015] 2023-12-23 23:16:03,132 - cortix - INFO - Leaching::run():time[d]=0.4
# [1015] 2023-12-23 23:16:03,360 - cortix - INFO - Leaching::run():time[d]=0.5
# [1015] 2023-12-23 23:16:03,535 - cortix - INFO - Leaching::run():time[d]=0.5
# [1015] 2023-12-23 23:16:03,649 - cortix - INFO - Leaching::run():time[d]=0.5
# [1015] 2023-12-23 23:16:03,768 - cortix - INFO - Leaching::run():time[d]=0.6
# [1015] 2023-12-23 23:16:03,882 - cortix - INFO - Leaching::run():time[d]=0.6
# [1015] 2023-12-23 23:16:03,991 - cortix - INFO - Leaching::run():time[d]=0.7
# [1015] 2023-12-23 23:16:04,101 - cortix - INFO - Leaching::run():time[d]=0.7
# [1015] 2023-12-23 23:16:04,204 - cortix - INFO - Leaching::run():time[d]=0.8
# [1015] 2023-12-23 23:16:04,312 - cortix - INFO - Leaching::run():time[d]=0.8
# [1015] 2023-12-23 23:16:04,535 - cortix - INFO - Leaching::run():time[d]=0.8
# [1015] 2023-12-23 23:16:04,750 - cortix - INFO - Leaching::run():time[d]=0.9
# [1015] 2023-12-23 23:16:04,951 - cortix - INFO - Leaching::run():time[d]=0.9
# [1015] 2023-12-23 23:16:05,164 - cortix - INFO - Leaching::run():time[d]=1.0
# [1015] 2023-12-23 23:16:05,405 - cortix - INFO - Leaching::run():time[d]=1.0
# [1015] 2023-12-23 23:16:05,525 - cortix - INFO - Leaching::run():time[d]=1.0
# [1015] 2023-12-23 23:16:05,638 - cortix - INFO - Leaching::run():time[d]=1.1
# [1015] 2023-12-23 23:16:05,742 - cortix - INFO - Leaching::run():time[d]=1.1
# [1015] 2023-12-23 23:16:05,855 - cortix - INFO - Leaching::run():time[d]=1.2
# [1015] 2023-12-23 23:16:05,966 - cortix - INFO - Leaching::run():time[d]=1.2
# [1015] 2023-12-23 23:16:06,086 - cortix - INFO - Leaching::run():time[d]=1.2
# [1015] 2023-12-23 23:16:06,198 - cortix - INFO - Leaching::run():time[d]=1.3
# [1015] 2023-12-23 23:16:06,350 - cortix - INFO - Leaching::run():time[d]=1.3
# [1015] 2023-12-23 23:16:06,642 - cortix - INFO - Leaching::run():time[d]=1.4
# [1015] 2023-12-23 23:16:06,903 - cortix - INFO - Leaching::run():time[d]=1.4
# [1015] 2023-12-23 23:16:07,115 - cortix - INFO - Leaching::run():time[d]=1.5
# [1015] 2023-12-23 23:16:07,367 - cortix - INFO - Leaching::run():time[d]=1.5
# [1015] 2023-12-23 23:16:07,505 - cortix - INFO - Leaching::run():time[d]=1.5
# [1015] 2023-12-23 23:16:07,642 - cortix - INFO - Leaching::run():time[d]=1.6
# [1015] 2023-12-23 23:16:07,779 - cortix - INFO - Leaching::run():time[d]=1.6
# [1015] 2023-12-23 23:16:07,904 - cortix - INFO - Leaching::run():time[d]=1.7
# [1015] 2023-12-23 23:16:08,143 - cortix - INFO - Leaching::run():time[d]=1.7
# [1015] 2023-12-23 23:16:08,315 - cortix - INFO - Leaching::run():time[d]=1.8
# [1015] 2023-12-23 23:16:08,529 - cortix - INFO - Leaching::run():time[d]=1.8
# [1015] 2023-12-23 23:16:08,747 - cortix - INFO - Leaching::run():time[d]=1.8
# [1015] 2023-12-23 23:16:08,970 - cortix - INFO - Leaching::run():time[d]=1.9
# [1015] 2023-12-23 23:16:09,159 - cortix - INFO - Leaching::run():time[d]=1.9
# [1015] 2023-12-23 23:16:09,343 - cortix - INFO - Leaching::run():time[d]=2.0
# [1015] 2023-12-23 23:16:09,439 - cortix - INFO - Leaching::run():time[d]=2.0
# [1015] 2023-12-23 23:16:09,531 - cortix - INFO - Leaching::run():time[d]=2.0
# [1015] 2023-12-23 23:16:09,619 - cortix - INFO - Leaching::run():time[d]=2.1
# [1015] 2023-12-23 23:16:09,706 - cortix - INFO - Leaching::run():time[d]=2.1
# [1015] 2023-12-23 23:16:09,806 - cortix - INFO - Leaching::run():time[d]=2.2
# [1015] 2023-12-23 23:16:09,908 - cortix - INFO - Leaching::run():time[d]=2.2
# [1015] 2023-12-23 23:16:10,010 - cortix - INFO - Leaching::run():time[d]=2.2
# [1015] 2023-12-23 23:16:10,115 - cortix - INFO - Leaching::run():time[d]=2.3
# [1015] 2023-12-23 23:16:10,266 - cortix - INFO - Leaching::run():time[d]=2.3
# [1015] 2023-12-23 23:16:10,535 - cortix - INFO - Leaching::run():time[d]=2.4
# [1015] 2023-12-23 23:16:10,818 - cortix - INFO - Leaching::run():time[d]=2.4
# [1015] 2023-12-23 23:16:11,092 - cortix - INFO - Leaching::run():time[d]=2.5
# [1015] 2023-12-23 23:16:11,301 - cortix - INFO - Leaching::run():time[d]=2.5
# [1015] 2023-12-23 23:16:11,411 - cortix - INFO - Leaching::run():time[d]=2.5
# [1015] 2023-12-23 23:16:11,516 - cortix - INFO - Leaching::run():time[d]=2.6
# [1015] 2023-12-23 23:16:11,619 - cortix - INFO - Leaching::run():time[d]=2.6
# [1015] 2023-12-23 23:16:11,723 - cortix - INFO - Leaching::run():time[d]=2.7
# [1015] 2023-12-23 23:16:11,860 - cortix - INFO - Leaching::run():time[d]=2.7
# [1015] 2023-12-23 23:16:11,972 - cortix - INFO - Leaching::run():time[d]=2.8
# [1015] 2023-12-23 23:16:12,101 - cortix - INFO - Leaching::run():time[d]=2.8
# [1015] 2023-12-23 23:16:12,273 - cortix - INFO - Leaching::run():time[d]=2.8
# [1015] 2023-12-23 23:16:12,464 - cortix - INFO - Leaching::run():time[d]=2.9
# [1015] 2023-12-23 23:16:12,762 - cortix - INFO - Leaching::run():time[d]=2.9
# [1015] 2023-12-23 23:16:13,043 - cortix - INFO - Leaching::run():time[d]=3.0
# [1015] 2023-12-23 23:16:13,256 - cortix - INFO - Leaching::run():time[d]=3.0
# [1015] 2023-12-23 23:16:13,364 - cortix - INFO - Leaching::run():time[d]=3.0
# [1015] 2023-12-23 23:16:13,476 - cortix - INFO - Leaching::run():time[d]=3.1
# [1015] 2023-12-23 23:16:13,586 - cortix - INFO - Leaching::run():time[d]=3.1
# [1015] 2023-12-23 23:16:13,693 - cortix - INFO - Leaching::run():time[d]=3.2
# [1015] 2023-12-23 23:16:13,801 - cortix - INFO - Leaching::run():time[d]=3.2
# [1015] 2023-12-23 23:16:13,903 - cortix - INFO - Leaching::run():time[d]=3.2
# [1015] 2023-12-23 23:16:14,004 - cortix - INFO - Leaching::run():time[d]=3.3
# [1015] 2023-12-23 23:16:14,152 - cortix - INFO - Leaching::run():time[d]=3.3
# [1015] 2023-12-23 23:16:14,378 - cortix - INFO - Leaching::run():time[d]=3.4
# [1015] 2023-12-23 23:16:14,595 - cortix - INFO - Leaching::run():time[d]=3.4
# [1015] 2023-12-23 23:16:14,803 - cortix - INFO - Leaching::run():time[d]=3.5
# [1015] 2023-12-23 23:16:15,015 - cortix - INFO - Leaching::run():time[d]=3.5
# [1015] 2023-12-23 23:16:15,210 - cortix - INFO - Leaching::run():time[d]=3.5
# [1015] 2023-12-23 23:16:15,341 - cortix - INFO - Leaching::run():time[d]=3.6
# [1015] 2023-12-23 23:16:15,471 - cortix - INFO - Leaching::run():time[d]=3.6
# [1015] 2023-12-23 23:16:15,623 - cortix - INFO - Leaching::run():time[d]=3.7
# [1015] 2023-12-23 23:16:15,754 - cortix - INFO - Leaching::run():time[d]=3.7
# [1015] 2023-12-23 23:16:15,870 - cortix - INFO - Leaching::run():time[d]=3.8
# [1015] 2023-12-23 23:16:16,023 - cortix - INFO - Leaching::run():time[d]=3.8
# [1015] 2023-12-23 23:16:16,347 - cortix - INFO - Leaching::run():time[d]=3.8
# [1015] 2023-12-23 23:16:16,590 - cortix - INFO - Leaching::run():time[d]=3.9
# [1015] 2023-12-23 23:16:16,824 - cortix - INFO - Leaching::run():time[d]=3.9
# [1015] 2023-12-23 23:16:17,101 - cortix - INFO - Leaching::run():time[d]=4.0
# [1015] 2023-12-23 23:16:17,196 - cortix - INFO - Leaching::run():time[d]=4.0
# [1015] 2023-12-23 23:16:17,294 - cortix - INFO - Leaching::run():time[d]=4.0
# [1015] 2023-12-23 23:16:17,396 - cortix - INFO - Leaching::run():time[d]=4.1
# [1015] 2023-12-23 23:16:17,504 - cortix - INFO - Leaching::run():time[d]=4.1
# [1015] 2023-12-23 23:16:17,611 - cortix - INFO - Leaching::run():time[d]=4.2
# [1015] 2023-12-23 23:16:17,709 - cortix - INFO - Leaching::run():time[d]=4.2
# [1015] 2023-12-23 23:16:17,805 - cortix - INFO - Leaching::run():time[d]=4.2
# [1015] 2023-12-23 23:16:17,907 - cortix - INFO - Leaching::run():time[d]=4.3
# [1015] 2023-12-23 23:16:18,032 - cortix - INFO - Leaching::run():time[d]=4.3
# [1015] 2023-12-23 23:16:18,251 - cortix - INFO - Leaching::run():time[d]=4.4
# [1015] 2023-12-23 23:16:18,456 - cortix - INFO - Leaching::run():time[d]=4.4
# [1015] 2023-12-23 23:16:18,651 - cortix - INFO - Leaching::run():time[d]=4.5
# [1015] 2023-12-23 23:16:18,843 - cortix - INFO - Leaching::run():time[d]=4.5
# [1015] 2023-12-23 23:16:19,071 - cortix - INFO - Leaching::run():time[d]=4.5
# [1015] 2023-12-23 23:16:19,168 - cortix - INFO - Leaching::run():time[d]=4.6
# [1015] 2023-12-23 23:16:19,269 - cortix - INFO - Leaching::run():time[d]=4.6
# [1015] 2023-12-23 23:16:19,366 - cortix - INFO - Leaching::run():time[d]=4.7
# [1015] 2023-12-23 23:16:19,462 - cortix - INFO - Leaching::run():time[d]=4.7
# [1015] 2023-12-23 23:16:19,564 - cortix - INFO - Leaching::run():time[d]=4.8
# [1015] 2023-12-23 23:16:19,669 - cortix - INFO - Leaching::run():time[d]=4.8
# [1015] 2023-12-23 23:16:19,814 - cortix - INFO - Leaching::run():time[d]=4.8
# [1015] 2023-12-23 23:16:20,109 - cortix - INFO - Leaching::run():time[d]=4.9
# [1015] 2023-12-23 23:16:20,333 - cortix - INFO - Leaching::run():time[d]=4.9
# [1015] 2023-12-23 23:16:20,575 - cortix - INFO - Leaching::run():time[d]=5.0
# [1015] 2023-12-23 23:16:20,789 - cortix - INFO - Leaching::run():time[d]=5.0
# [1015] 2023-12-23 23:16:21,022 - cortix - INFO - Leaching::run():time[d]=5.0
# [1015] 2023-12-23 23:16:21,127 - cortix - INFO - Leaching::run():time[d]=5.1
# [1015] 2023-12-23 23:16:21,281 - cortix - INFO - Leaching::run():time[d]=5.1
# [1015] 2023-12-23 23:16:21,395 - cortix - INFO - Leaching::run():time[d]=5.2
# [1015] 2023-12-23 23:16:21,562 - cortix - INFO - Leaching::run():time[d]=5.2
# [1015] 2023-12-23 23:16:21,707 - cortix - INFO - Leaching::run():time[d]=5.2
# [1015] 2023-12-23 23:16:21,839 - cortix - INFO - Leaching::run():time[d]=5.3
# [1015] 2023-12-23 23:16:22,048 - cortix - INFO - Leaching::run():time[d]=5.3
# [1015] 2023-12-23 23:16:22,289 - cortix - INFO - Leaching::run():time[d]=5.4
# [1015] 2023-12-23 23:16:22,508 - cortix - INFO - Leaching::run():time[d]=5.4
# [1015] 2023-12-23 23:16:22,748 - cortix - INFO - Leaching::run():time[d]=5.5
# [1015] 2023-12-23 23:16:23,010 - cortix - INFO - Leaching::run():time[d]=5.5
# [1015] 2023-12-23 23:16:23,183 - cortix - INFO - Leaching::run():time[d]=5.5
# [1015] 2023-12-23 23:16:23,294 - cortix - INFO - Leaching::run():time[d]=5.6
# [1015] 2023-12-23 23:16:23,425 - cortix - INFO - Leaching::run():time[d]=5.6
# [1015] 2023-12-23 23:16:23,562 - cortix - INFO - Leaching::run():time[d]=5.7
# [1015] 2023-12-23 23:16:23,690 - cortix - INFO - Leaching::run():time[d]=5.7
# [1015] 2023-12-23 23:16:23,795 - cortix - INFO - Leaching::run():time[d]=5.8
# [1015] 2023-12-23 23:16:23,982 - cortix - INFO - Leaching::run():time[d]=5.8
# [1015] 2023-12-23 23:16:24,204 - cortix - INFO - Leaching::run():time[d]=5.8
# [1015] 2023-12-23 23:16:24,454 - cortix - INFO - Leaching::run():time[d]=5.9
# [1015] 2023-12-23 23:16:24,723 - cortix - INFO - Leaching::run():time[d]=5.9
# [1015] 2023-12-23 23:16:24,952 - cortix - INFO - Leaching::run():time[d]=6.0
# [1015] 2023-12-23 23:16:25,065 - cortix - INFO - Leaching::run():time[d]=6.0
# [1015] 2023-12-23 23:16:25,175 - cortix - INFO - Leaching::run():time[d]=6.0
# [1015] 2023-12-23 23:16:25,283 - cortix - INFO - Leaching::run():time[d]=6.1
# [1015] 2023-12-23 23:16:25,412 - cortix - INFO - Leaching::run():time[d]=6.1
# [1015] 2023-12-23 23:16:25,528 - cortix - INFO - Leaching::run():time[d]=6.2
# [1015] 2023-12-23 23:16:25,692 - cortix - INFO - Leaching::run():time[d]=6.2
# [1015] 2023-12-23 23:16:25,861 - cortix - INFO - Leaching::run():time[d]=6.2
# [1015] 2023-12-23 23:16:26,166 - cortix - INFO - Leaching::run():time[d]=6.3
# [1015] 2023-12-23 23:16:26,403 - cortix - INFO - Leaching::run():time[d]=6.3
# [1015] 2023-12-23 23:16:26,673 - cortix - INFO - Leaching::run():time[d]=6.4
# [1015] 2023-12-23 23:16:26,913 - cortix - INFO - Leaching::run():time[d]=6.4
# [1015] 2023-12-23 23:16:27,074 - cortix - INFO - Leaching::run():time[d]=6.5
# [1015] 2023-12-23 23:16:27,205 - cortix - INFO - Leaching::run():time[d]=6.5
# [1015] 2023-12-23 23:16:27,342 - cortix - INFO - Leaching::run():time[d]=6.5
# [1015] 2023-12-23 23:16:27,464 - cortix - INFO - Leaching::run():time[d]=6.6
# [1015] 2023-12-23 23:16:27,593 - cortix - INFO - Leaching::run():time[d]=6.6
# [1015] 2023-12-23 23:16:27,745 - cortix - INFO - Leaching::run():time[d]=6.7
# [1015] 2023-12-23 23:16:28,024 - cortix - INFO - Leaching::run():time[d]=6.7
# [1015] 2023-12-23 23:16:28,286 - cortix - INFO - Leaching::run():time[d]=6.8
# [1015] 2023-12-23 23:16:28,545 - cortix - INFO - Leaching::run():time[d]=6.8
# [1015] 2023-12-23 23:16:28,834 - cortix - INFO - Leaching::run():time[d]=6.8
# [1015] 2023-12-23 23:16:28,953 - cortix - INFO - Leaching::run():time[d]=6.9
# [1015] 2023-12-23 23:16:29,074 - cortix - INFO - Leaching::run():time[d]=6.9
# [1015] 2023-12-23 23:16:29,193 - cortix - INFO - Leaching::run():time[d]=7.0
# [1015] 2023-12-23 23:16:29,314 - cortix - INFO - Leaching::run():time[d]=7.0
# [1015] 2023-12-23 23:16:29,474 - cortix - INFO - Leaching::run():time[d]=7.0
# [1015] 2023-12-23 23:16:29,602 - cortix - INFO - Leaching::run():time[d]=7.1
# [1015] 2023-12-23 23:16:29,714 - cortix - INFO - Leaching::run():time[d]=7.1
# [1015] 2023-12-23 23:16:29,924 - cortix - INFO - Leaching::run():time[d]=7.2
# [1015] 2023-12-23 23:16:30,163 - cortix - INFO - Leaching::run():time[d]=7.2
# [1015] 2023-12-23 23:16:30,423 - cortix - INFO - Leaching::run():time[d]=7.2
# [1015] 2023-12-23 23:16:30,698 - cortix - INFO - Leaching::run():time[d]=7.3
# [1015] 2023-12-23 23:16:30,886 - cortix - INFO - Leaching::run():time[d]=7.3
# [1015] 2023-12-23 23:16:31,004 - cortix - INFO - Leaching::run():time[d]=7.4
# [1015] 2023-12-23 23:16:31,123 - cortix - INFO - Leaching::run():time[d]=7.4
# [1015] 2023-12-23 23:16:31,261 - cortix - INFO - Leaching::run():time[d]=7.5
# [1015] 2023-12-23 23:16:31,393 - cortix - INFO - Leaching::run():time[d]=7.5
# [1015] 2023-12-23 23:16:31,510 - cortix - INFO - Leaching::run():time[d]=7.5
# [1015] 2023-12-23 23:16:31,613 - cortix - INFO - Leaching::run():time[d]=7.6
# [1015] 2023-12-23 23:16:31,754 - cortix - INFO - Leaching::run():time[d]=7.6
# [1015] 2023-12-23 23:16:31,942 - cortix - INFO - Leaching::run():time[d]=7.7
# [1015] 2023-12-23 23:16:32,133 - cortix - INFO - Leaching::run():time[d]=7.7
# [1015] 2023-12-23 23:16:32,355 - cortix - INFO - Leaching::run():time[d]=7.8
# [1015] 2023-12-23 23:16:32,583 - cortix - INFO - Leaching::run():time[d]=7.8
# [1015] 2023-12-23 23:16:32,806 - cortix - INFO - Leaching::run():time[d]=7.8
# [1015] 2023-12-23 23:16:32,926 - cortix - INFO - Leaching::run():time[d]=7.9
# [1015] 2023-12-23 23:16:33,019 - cortix - INFO - Leaching::run():time[d]=7.9
# [1015] 2023-12-23 23:16:33,119 - cortix - INFO - Leaching::run():time[d]=8.0
# [1015] 2023-12-23 23:16:33,218 - cortix - INFO - Leaching::run():time[d]=8.0
# [1015] 2023-12-23 23:16:33,318 - cortix - INFO - Leaching::run():time[d]=8.0
# [1015] 2023-12-23 23:16:33,430 - cortix - INFO - Leaching::run():time[d]=8.1
# [1015] 2023-12-23 23:16:33,535 - cortix - INFO - Leaching::run():time[d]=8.1
# [1015] 2023-12-23 23:16:33,634 - cortix - INFO - Leaching::run():time[d]=8.2
# [1015] 2023-12-23 23:16:33,851 - cortix - INFO - Leaching::run():time[d]=8.2
# [1015] 2023-12-23 23:16:34,060 - cortix - INFO - Leaching::run():time[d]=8.2
# [1015] 2023-12-23 23:16:34,266 - cortix - INFO - Leaching::run():time[d]=8.3
# [1015] 2023-12-23 23:16:34,485 - cortix - INFO - Leaching::run():time[d]=8.3
# [1015] 2023-12-23 23:16:34,705 - cortix - INFO - Leaching::run():time[d]=8.4
# [1015] 2023-12-23 23:16:34,801 - cortix - INFO - Leaching::run():time[d]=8.4
# [1015] 2023-12-23 23:16:34,909 - cortix - INFO - Leaching::run():time[d]=8.5
# [1015] 2023-12-23 23:16:35,022 - cortix - INFO - Leaching::run():time[d]=8.5
# [1015] 2023-12-23 23:16:35,136 - cortix - INFO - Leaching::run():time[d]=8.5
# [1015] 2023-12-23 23:16:35,239 - cortix - INFO - Leaching::run():time[d]=8.6
# [1015] 2023-12-23 23:16:35,337 - cortix - INFO - Leaching::run():time[d]=8.6
# [1015] 2023-12-23 23:16:35,433 - cortix - INFO - Leaching::run():time[d]=8.7
# [1015] 2023-12-23 23:16:35,540 - cortix - INFO - Leaching::run():time[d]=8.7
# [1015] 2023-12-23 23:16:35,728 - cortix - INFO - Leaching::run():time[d]=8.8
# [1015] 2023-12-23 23:16:35,941 - cortix - INFO - Leaching::run():time[d]=8.8
# [1015] 2023-12-23 23:16:36,145 - cortix - INFO - Leaching::run():time[d]=8.8
# [1015] 2023-12-23 23:16:36,412 - cortix - INFO - Leaching::run():time[d]=8.9
# [1015] 2023-12-23 23:16:36,662 - cortix - INFO - Leaching::run():time[d]=8.9
# [1015] 2023-12-23 23:16:36,810 - cortix - INFO - Leaching::run():time[d]=9.0
# [1015] 2023-12-23 23:16:37,003 - cortix - INFO - Leaching::run():time[d]=9.0
# [1015] 2023-12-23 23:16:37,175 - cortix - INFO - Leaching::run():time[d]=9.0
# [1015] 2023-12-23 23:16:37,299 - cortix - INFO - Leaching::run():time[d]=9.1
# [1015] 2023-12-23 23:16:37,458 - cortix - INFO - Leaching::run():time[d]=9.1
# [1015] 2023-12-23 23:16:37,657 - cortix - INFO - Leaching::run():time[d]=9.2
# [1015] 2023-12-23 23:16:37,974 - cortix - INFO - Leaching::run():time[d]=9.2
# [1015] 2023-12-23 23:16:38,206 - cortix - INFO - Leaching::run():time[d]=9.2
# [1015] 2023-12-23 23:16:38,501 - cortix - INFO - Leaching::run():time[d]=9.3
# [1015] 2023-12-23 23:16:38,726 - cortix - INFO - Leaching::run():time[d]=9.3
# [1015] 2023-12-23 23:16:38,895 - cortix - INFO - Leaching::run():time[d]=9.4
# [1015] 2023-12-23 23:16:39,024 - cortix - INFO - Leaching::run():time[d]=9.4
# [1015] 2023-12-23 23:16:39,130 - cortix - INFO - Leaching::run():time[d]=9.5
# [1015] 2023-12-23 23:16:39,233 - cortix - INFO - Leaching::run():time[d]=9.5
# [1015] 2023-12-23 23:16:39,341 - cortix - INFO - Leaching::run():time[d]=9.5
# [1015] 2023-12-23 23:16:39,450 - cortix - INFO - Leaching::run():time[d]=9.6
# [1015] 2023-12-23 23:16:39,657 - cortix - INFO - Leaching::run():time[d]=9.6
# [1015] 2023-12-23 23:16:39,889 - cortix - INFO - Leaching::run():time[d]=9.7
# [1015] 2023-12-23 23:16:40,118 - cortix - INFO - Leaching::run():time[d]=9.7
# [1015] 2023-12-23 23:16:40,308 - cortix - INFO - Leaching::run():time[d]=9.8
# [1015] 2023-12-23 23:16:40,574 - cortix - INFO - Leaching::run():time[d]=9.8
# [1015] 2023-12-23 23:16:40,700 - cortix - INFO - Leaching::run():time[d]=9.8
# [1015] 2023-12-23 23:16:40,840 - cortix - INFO - Leaching::run():time[d]=9.9
# [1015] 2023-12-23 23:16:40,960 - cortix - INFO - Leaching::run():time[d]=9.9
# [1015] 2023-12-23 23:16:41,081 - cortix - INFO - Leaching::run():time[d]=10.0
# [1015] 2023-12-23 23:16:41,205 - cortix - INFO - Leaching::run():time[d]=10.0
# [1015] 2023-12-23 23:16:41,240 - cortix - INFO - run()::Elapsed wall clock time [s]: 40.33
# [1015] 2023-12-23 23:16:41,243 - cortix - INFO - Closed Cortix object.
# _____________________________________________________________________________
#                            T E R M I N A T I N G
# _____________________________________________________________________________
#       ...                                        s       .     (TAAG Fraktur)
#    xH88"`~ .x8X                                 :8      @88>
#  :8888   .f"8888Hf        u.      .u    .      .88      %8P      uL   ..
# :8888>  X8L  ^""`   ...ue888b   .d88B :@8c    :888ooo    .     .@88b  @88R
# X8888  X888h        888R Y888r ="8888f8888r -*8888888  .@88u  ""Y888k/"*P
# 88888  !88888.      888R I888>   4888>"88"    8888    888E`    Y888L
# 88888   %88888      888R I888>   4888> "      8888      888E      8888
# 88888 `> `8888>     888R I888>   4888>        8888      888E      `888N
# `8888L %  ?888   ! u8888cJ888   .d888L .+    .8888Lu=   888E   .u./"888&
#  `8888  `-*""   /   "*888*P"    ^"8888*"     ^%888*     888&  d888" Y888*"
#    "888.      :"      "Y"          "Y"         "Y"      R888" ` "Y   Y"
#      `""***~"`                                           ""
#                              https://cortix.org
# _____________________________________________________________________________
# [1015] 2023-12-23 23:16:41,247 - cortix - INFO - close()::Elapsed wall clock time [s]: 40.34

# %%
'''Recover modules data'''
leaching = wm_net.modules[0]

# %%
'''Leaching data'''
leaching.preleach_phase.plot(['liquid-volume','mass-flowrate','mass-density'],show=True,figsize=[14,8])
leaching.acidleach_phase.plot(['liquid-volume','mass-flowrate','mass-density'],show=True,figsize=[14,8])

# %% [markdown]
# ## [References](#toc)<a id="refs"></a>
